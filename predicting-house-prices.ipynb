# %% [markdown]
# <hr/>
#
# # Predicting House Prices (Keras - Artificial Neural Network)
# **[by Tomas Mantero](https://www.kaggle.com/tomasmantero)**
# <hr/>
#
# ### Table of Contents
# 1. [Overview](#ch1)
# 1. [Dataset](#ch2)
# 1. [Exploratory Data Analysis](#ch3)
# 1. [Working with Feature Data](#ch4)
# 1. [Feature Engineering](#ch5)
# 1. [Scaling and Train Test Split](#ch6)
# 1. [Creating a Model](#ch7)
# 1. [Training the Model](#ch8)
# 1. [Evaluation on Test Data](#ch9)
# 1. [Predicting on a Brand New House](#ch10)

# %% [markdown]
# <a id="ch1"></a>
# ## Overview
# <hr/>
#
# One of the objectives of this notebook is to **show step-by-step how to analyze and visualize the dataset to predict future home prices.** Moreover, we are going to explain most of the concepts used so that you understand why we are using them.
# In base of features like sqft_living, bathrooms, bedrooms, view, and others, we are going to build a deep learning model that can predict future price houses.
#
# If you have a question or feedback, do not hesitate to write and if you like this kernel,<b><font color='green'> please upvote! </font></b>
#
# <img src="https://images.pexels.com/photos/1546168/pexels-photo-1546168.jpeg?auto=compress&cs=tinysrgb&dpr=3&h=750&w=1260" title="source: www.pexels.com" />
# <br>
#
# The following questions will be answered throughout the Kernel:
# * ***Which features are available in the dataset?***
# * ***Which features are categorical?***
# * ***Which features are numerical?***
# * ***Which features contain blank, null or empty values?***
# * ***What are the data types for various features?***
# * ***What is the distribution of numerical feature values across the samples?***
# * ***Which features are more correlated to the price?***

# %% [markdown]
# <a id="ch2"></a>
# ## Dataset
# <hr/>
#
# * This dataset contains house sale prices for King County, which includes Seattle.
# * It includes homes sold between May 2014 and May 2015.
# * 21 columns. (features)
# * 21597 rows.
#
# ***Feature Columns***
#
# * **id:** Unique ID for each home sold
# * **date:** Date of the home sale
# * **price:** Price of each home sold
# * **bedrooms:** Number of bedrooms
# * **bathrooms:** Number of bathrooms, where .5 accounts for a room with a toilet but no shower
# * **sqft_living:** Square footage of the apartments interior living space
# * **sqft_lot:** Square footage of the land space
# * **floors:** Number of floors
# * **waterfront:** - A dummy variable for whether the apartment was overlooking the waterfront or not
# * **view:** An index from 0 to 4 of how good the view of the property was
# * **condition:** - An index from 1 to 5 on the condition of the apartment,
# * **grade:** An index from 1 to 13, where 1-3 falls short of building construction and design, 7 has an average level of construction and design, and 11-13 have a high quality level of construction and design.
# * **sqft_above:** The square footage of the interior housing space that is above ground level
# * **sqft_basement:** The square footage of the interior housing space that is below ground level
# * **yr_built:** The year the house was initially built
# * **yr_renovated:** The year of the house’s last renovation
# * **zipcode:** What zipcode area the house is in
# * **lat:** Lattitude
# * **long:** Longitude
# * **sqft_living15:** The square footage of interior housing living space for the nearest 15 neighbors
# * **sqft_lot15:** The square footage of the land lots of the nearest 15 neighbors

# %% [markdown]
# ### Imports

# %%
# data analysis and wrangling
import pandas as pd
import numpy as np
import random as rnd

# visualization
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# scaling and train test split
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler

# creating a model
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation
from tensorflow.keras.optimizers import Adam

# evaluation on test data
from sklearn.metrics import mean_squared_error,mean_absolute_error,explained_variance_score
from sklearn.metrics import classification_report,confusion_matrix

df = pd.read_csv('kc_house_data.csv')

# %% [markdown]
# ### Acquire data
# The Python Pandas packages helps us work with our datasets. We start by acquiring the datasets into Pandas DataFrames.

# %% [markdown]
# ### Analyze by describing data
# Pandas also helps describe the datasets answering following questions early in our project.
#
# ***Which features are available in the dataset?***

# %%
print(df.columns.values)
# Out:
# ['id' 'date' 'price' 'bedrooms' 'bathrooms' 'sqft_living' 'sqft_lot'
#  'floors' 'waterfront' 'view' 'condition' 'grade' 'sqft_above'
#  'sqft_basement' 'yr_built' 'yr_renovated' 'zipcode' 'lat' 'long'
#  'sqft_living15' 'sqft_lot15']

# %% [markdown]
# ***Which features are categorical?***
#
# These values classify the samples into sets of similar samples. Within categorical features are the values nominal, ordinal, ratio, or interval based? Among other things this helps us select the appropriate plots for visualization.
#
# * Categorical: id, waterfront, zipcode.
#
# ***Which features are numerical?***
#
# Which features are numerical? These values change from sample to sample. Within numerical features are the values discrete, continuous, or timeseries based? Among other things this helps us select the appropriate plots for visualization.
#
# * Continous: price, bathrooms, floors, lat, long.
# * Discrete: date, bedrooms, sqft_living, sqft_lot, view, condition, grade, sqft_above, sqft_basement, yr_built, yr_renovated, sqft_living15, sqft_lot15.

# %%
# preview the data
df.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
#    yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# 0      1955             0    98178  47.5112 -122.257           1340
# 1      1951          1991    98125  47.7210 -122.319           1690
# 2      1933             0    98028  47.7379 -122.233           2720
# 3      1965             0    98136  47.5208 -122.393           1360
# 4      1987             0    98074  47.6168 -122.045           1800
#
#    sqft_lot15
# 0        5650
# 1        7639
# 2        8062
# 3        5000
# 4        7503
#
# [5 rows x 21 columns]

# %%
# preview the data
df.tail()
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 21608   263000018  20140521T000000  360000.0         3       2.50
# 21609  6600060120  20150223T000000  400000.0         4       2.50
# 21610  1523300141  20140623T000000  402101.0         2       0.75
# 21611   291310100  20150116T000000  400000.0         3       2.50
# 21612  1523300157  20141015T000000  325000.0         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 21608         1530      1131     3.0           0     0  ...      8
# 21609         2310      5813     2.0           0     0  ...      8
# 21610         1020      1350     2.0           0     0  ...      7
# 21611         1600      2388     2.0           0     0  ...      8
# 21612         1020      1076     2.0           0     0  ...      7
#
#        sqft_above  sqft_basement  yr_built  yr_renovated  zipcode      lat  \
# 21608        1530              0      2009             0    98103  47.6993
# 21609        2310              0      2014             0    98146  47.5107
# 21610        1020              0      2009             0    98144  47.5944
# 21611        1600              0      2004             0    98027  47.5345
# 21612        1020              0      2008             0    98144  47.5941
#
#           long  sqft_living15  sqft_lot15
# 21608 -122.346           1530        1509
# 21609 -122.362           1830        7200
# 21610 -122.299           1020        2007
# 21611 -122.069           1410        1287
# 21612 -122.299           1020        1357
#
# [5 rows x 21 columns]

# %% [markdown]
# ***Which features contain blank, null or empty values?***
#
# We can check for missing values with pandas isnull(). This indicates whether values are missing or not. Then we can sum all the values to check every column.

# %%
# No missing values
df.isnull().sum()
# Out:
# id               0
# date             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# grade            0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# zipcode          0
# lat              0
# long             0
# sqft_living15    0
# sqft_lot15       0
# dtype: int64

# %% [markdown]
# ***What are the data types for various features?***
#
# Five features are floats, fifteen are integers and one is an object.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21613 non-null  int64
#  1   date           21613 non-null  object
#  2   price          21613 non-null  float64
#  3   bedrooms       21613 non-null  int64
#  4   bathrooms      21613 non-null  float64
#  5   sqft_living    21613 non-null  int64
#  6   sqft_lot       21613 non-null  int64
#  7   floors         21613 non-null  float64
#  8   waterfront     21613 non-null  int64
#  9   view           21613 non-null  int64
#  10  condition      21613 non-null  int64
#  11  grade          21613 non-null  int64
#  12  sqft_above     21613 non-null  int64
#  13  sqft_basement  21613 non-null  int64
#  14  yr_built       21613 non-null  int64
#  15  yr_renovated   21613 non-null  int64
#  16  zipcode        21613 non-null  int64
#  17  lat            21613 non-null  float64
#  18  long           21613 non-null  float64
#  19  sqft_living15  21613 non-null  int64
#  20  sqft_lot15     21613 non-null  int64
# dtypes: float64(5), int64(15), object(1)
# memory usage: 3.5+ MB

# %% [markdown]
# ***What is the distribution of numerical feature values across the samples?***

# %%
df.describe().transpose()
# Out:
#                  count          mean           std           min  \
# id             21613.0  4.580302e+09  2.876566e+09  1.000102e+06
# price          21613.0  5.400881e+05  3.671272e+05  7.500000e+04
# bedrooms       21613.0  3.370842e+00  9.300618e-01  0.000000e+00
# bathrooms      21613.0  2.114757e+00  7.701632e-01  0.000000e+00
# sqft_living    21613.0  2.079900e+03  9.184409e+02  2.900000e+02
# sqft_lot       21613.0  1.510697e+04  4.142051e+04  5.200000e+02
# floors         21613.0  1.494309e+00  5.399889e-01  1.000000e+00
# waterfront     21613.0  7.541757e-03  8.651720e-02  0.000000e+00
# view           21613.0  2.343034e-01  7.663176e-01  0.000000e+00
# condition      21613.0  3.409430e+00  6.507430e-01  1.000000e+00
# grade          21613.0  7.656873e+00  1.175459e+00  1.000000e+00
# sqft_above     21613.0  1.788391e+03  8.280910e+02  2.900000e+02
# sqft_basement  21613.0  2.915090e+02  4.425750e+02  0.000000e+00
# yr_built       21613.0  1.971005e+03  2.937341e+01  1.900000e+03
# yr_renovated   21613.0  8.440226e+01  4.016792e+02  0.000000e+00
# zipcode        21613.0  9.807794e+04  5.350503e+01  9.800100e+04
# lat            21613.0  4.756005e+01  1.385637e-01  4.715590e+01
# long           21613.0 -1.222139e+02  1.408283e-01 -1.225190e+02
# sqft_living15  21613.0  1.986552e+03  6.853913e+02  3.990000e+02
# sqft_lot15     21613.0  1.276846e+04  2.730418e+04  6.510000e+02
#
#                         25%           50%           75%           max
# id             2.123049e+09  3.904930e+09  7.308900e+09  9.900000e+09
# price          3.219500e+05  4.500000e+05  6.450000e+05  7.700000e+06
# bedrooms       3.000000e+00  3.000000e+00  4.000000e+00  3.300000e+01
# bathrooms      1.750000e+00  2.250000e+00  2.500000e+00  8.000000e+00
# sqft_living    1.427000e+03  1.910000e+03  2.550000e+03  1.354000e+04
# sqft_lot       5.040000e+03  7.618000e+03  1.068800e+04  1.651359e+06
# floors         1.000000e+00  1.500000e+00  2.000000e+00  3.500000e+00
# waterfront     0.000000e+00  0.000000e+00  0.000000e+00  1.000000e+00
# view           0.000000e+00  0.000000e+00  0.000000e+00  4.000000e+00
# condition      3.000000e+00  3.000000e+00  4.000000e+00  5.000000e+00
# grade          7.000000e+00  7.000000e+00  8.000000e+00  1.300000e+01
# sqft_above     1.190000e+03  1.560000e+03  2.210000e+03  9.410000e+03
# sqft_basement  0.000000e+00  0.000000e+00  5.600000e+02  4.820000e+03
# yr_built       1.951000e+03  1.975000e+03  1.997000e+03  2.015000e+03
# yr_renovated   0.000000e+00  0.000000e+00  0.000000e+00  2.015000e+03
# zipcode        9.803300e+04  9.806500e+04  9.811800e+04  9.819900e+04
# lat            4.747100e+01  4.757180e+01  4.767800e+01  4.777760e+01
# long          -1.223280e+02 -1.222300e+02 -1.221250e+02 -1.213150e+02
# sqft_living15  1.490000e+03  1.840000e+03  2.360000e+03  6.210000e+03
# sqft_lot15     5.100000e+03  7.620000e+03  1.008300e+04  8.712000e+05

# %% [markdown]
# ### Assumtions based on data analysis
#
# We arrive at following assumptions based on data analysis done so far. We may validate these assumptions further before taking appropriate actions.
#
# ### Correlating
#
# We want to know how well does each feature correlate with Price. We want to do this early in our project and match these quick correlations with modelled correlations later in the project.
#
# ### Completing
#
# Since there are no missing values we do not need to complete any values.
#
# ### Correcting
#
# Id feature may be dropped from our analysis since it does not add value.
# Date feature may be dropped since we are going to do feature engineering and make a year and month column.
# Zipcode feature is a special case, we could use it, but since we do not know exactly the zones of King County we are just going to drop it.
#
# ### Creating
#
# We may want to create a new feature called Year based on Date to analyze the price change throughout the years.
# We may want to create a new feature called Month based on Date to analyze the price change throughout the months.

# %% [markdown]
# <a id="ch3"></a>
# ## Exploratory Data Analysis
# <hr/>
#
# ### Analyze by visualizing data
# Now we can continue confirming some of our assumptions using visualizations for analyzing the data.

# %% [markdown]
# ### Pearson correlation matrix
# We use the Pearson correlation coefficient to examine the strength and direction of the linear relationship between two continuous variables.
#
# The correlation coefficient can range in value from −1 to +1. The larger the absolute value of the coefficient, the stronger the relationship between the variables. For the Pearson correlation, an absolute value of 1 indicates a perfect linear relationship. A correlation close to 0 indicates no linear relationship between the variables.
#
# The sign of the coefficient indicates the direction of the relationship. If both variables tend to increase or decrease together, the coefficient is positive, and the line that represents the correlation slopes upward. If one variable tends to increase as the other decreases, the coefficient is negative, and the line that represents the correlation slopes downward.

# %%
sns.set(style="whitegrid", font_scale=1)

plt.figure(figsize=(13,13))
plt.title('Pearson Correlation Matrix',fontsize=25)
sns.heatmap(df.corr(),linewidths=0.25,vmax=0.7,square=True,cmap="GnBu",linecolor='w',
            annot=True, annot_kws={"size":7}, cbar_kws={"shrink": .7})
# Out:
# <Axes: title={'center': 'Pearson Correlation Matrix'}>

# %% [markdown]
# ### Price correlation
# * This allow us to explore labels that are highly correlated to the price.
# * sqft_living looks like a highly correlated label to the price, as well as grade, sqft_above, sqft_living15 and bathrooms.
#
# ***Which features are more correlated to the price?***

# %%
price_corr = df.corr()['price'].sort_values(ascending=False)
print(price_corr)
# Out:
# price            1.000000
# sqft_living      0.702035
# grade            0.667434
# sqft_above       0.605567
# sqft_living15    0.585379
# bathrooms        0.525138
# view             0.397293
# sqft_basement    0.323816
# bedrooms         0.308350
# lat              0.307003
# waterfront       0.266369
# floors           0.256794
# yr_renovated     0.126434
# sqft_lot         0.089661
# sqft_lot15       0.082447
# yr_built         0.054012
# condition        0.036362
# long             0.021626
# id              -0.016762
# zipcode         -0.053203
# Name: price, dtype: float64

# %% [markdown]
# ### Price feature
# * Most of the house prices are between \\$0 and \\$1,500,000.
# * The average house price is \\$540,000.
# * Keep in mind that it may be a good idea to drop extreme values. For instance, we could focus on house from \\$0 to \\$3,000,000 and drop the other ones.
# * It seems that there is a positive linear relationship between the price and sqft_living.
# * An increase in living space generally corresponds to an increase in house price.

# %%
f, axes = plt.subplots(1, 2,figsize=(15,5))
sns.distplot(df['price'], ax=axes[0])
sns.scatterplot(x='price',y='sqft_living', data=df, ax=axes[1])
sns.despine(bottom=True, left=True)
axes[0].set(xlabel='Price in millions [USD]', ylabel='', title='Price Distribuition')
axes[1].set(xlabel='Price', ylabel='Sqft Living', title='Price vs Sqft Living')
axes[1].yaxis.set_label_position("right")
axes[1].yaxis.tick_right()
# Out:
# C:\Users\meetr\AppData\Local\Temp\ipykernel_6208\636539046.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['price'], ax=axes[0])

# %% [markdown]
# ### Bedrooms and floors box plots
# Box plot is a method for graphically depicting groups of numerical data through their quartiles. Box plots may also have lines extending from the boxes (whiskers) indicating variability outside the upper and lower quartiles, hence the terms box-and-whisker plot. Outliers may be plotted as individual points. The spacings between the different parts of the box indicate the degree of dispersion (spread).
#
# * We can see outliers plotted as individual points; this probably are the more expensive houses.
# * We can see that the price tends to go up when the house has more bedrooms.

# %%
sns.set(style="whitegrid", font_scale=1)

f, axes = plt.subplots(1, 2,figsize=(15,5))
sns.boxplot(x=df['bedrooms'],y=df['price'], ax=axes[0])
sns.boxplot(x=df['floors'],y=df['price'], ax=axes[1])
sns.despine(bottom=True, left=True)
axes[0].set(xlabel='Bedrooms', ylabel='Price', title='Bedrooms vs Price Box Plot')
axes[1].set(xlabel='Floors', ylabel='Price', title='Floors vs Price Box Plot')
# Out:
# [Text(0.5, 0, 'Floors'),
#  Text(0, 0.5, 'Price'),
#  Text(0.5, 1.0, 'Floors vs Price Box Plot')]

# %% [markdown]
# ### Waterfront, view and grade box plots
# * Waterfront houses tends to have a better price value.
# * The price of waterfront houses tends to be more disperse and the price of houses without waterfront tend to be more concentrated.
# * Grade and waterfront effect price. View seem to effect less but it also has an effect on price.

# %%
f, axes = plt.subplots(1, 2,figsize=(15,5))
sns.boxplot(x=df['waterfront'],y=df['price'], ax=axes[0])
sns.boxplot(x=df['view'],y=df['price'], ax=axes[1])
sns.despine(left=True, bottom=True)
axes[0].set(xlabel='Waterfront', ylabel='Price', title='Waterfront vs Price Box Plot')
axes[1].set(xlabel='View', ylabel='Price', title='View vs Price Box Plot')

f, axe = plt.subplots(1, 1,figsize=(15,5))
sns.boxplot(x=df['grade'],y=df['price'], ax=axe)
sns.despine(left=True, bottom=True)
axe.set(xlabel='Grade', ylabel='Price', title='Grade vs Price Box Plot')
# Out:
# [Text(0.5, 0, 'Grade'),
#  Text(0, 0.5, 'Price'),
#  Text(0.5, 1.0, 'Grade vs Price Box Plot')]

# %% [markdown]
# <a id="ch4"></a>
# ## Working with Feature Data
# <hr/>
#
# ### Correcting by dropping features
# By dropping features, we are dealing with fewer data points. Speeds up our notebook and eases the analysis. Based on our assumptions and decisions we want to drop the Id, zipcode and Date features.

# %%
df = df.drop('id', axis=1)
df = df.drop('zipcode',axis=1)

# %% [markdown]
# <a id="ch5"></a>
# ## Feature engineering
# <hr/>
#
# We want to engineer the date feature to make a year and month column. The feature date is as a string. With pd.to_datetime we can convert an argument to datetime.

# %%
df['date'] = pd.to_datetime(df['date'])

df['month'] = df['date'].apply(lambda date:date.month)
df['year'] = df['date'].apply(lambda date:date.year)

df = df.drop('date',axis=1)

# Check the new columns
print(df.columns.values)
# Out:
# ['price' 'bedrooms' 'bathrooms' 'sqft_living' 'sqft_lot' 'floors'
#  'waterfront' 'view' 'condition' 'grade' 'sqft_above' 'sqft_basement'
#  'yr_built' 'yr_renovated' 'lat' 'long' 'sqft_living15' 'sqft_lot15'
#  'month' 'year']

# %% [markdown]
# ### House price trends
# * Looking the box plots we notice that there is not a big difference between 2014 and 2015.
# * The number of houses sold by month tends to be similar every month.
# * The line plot show that around April there is an increase in house prices.

# %%
f, axes = plt.subplots(1, 2,figsize=(15,5))
sns.boxplot(x='year',y='price',data=df, ax=axes[0])
sns.boxplot(x='month',y='price',data=df, ax=axes[1])
sns.despine(left=True, bottom=True)
axes[0].set(xlabel='Year', ylabel='Price', title='Price by Year Box Plot')
axes[1].set(xlabel='Month', ylabel='Price', title='Price by Month Box Plot')

f, axe = plt.subplots(1, 1,figsize=(15,5))
df.groupby('month').mean()['price'].plot()
sns.despine(left=True, bottom=True)
axe.set(xlabel='Month', ylabel='Price', title='Price Trends')
# Out:
# [Text(0.5, 0, 'Month'), Text(0, 0.5, 'Price'), Text(0.5, 1.0, 'Price Trends')]

# %% [markdown]
# <a id="ch6"></a>
# ## Scaling and train test split
# <hr/>
# Now we are ready to train a model and predict the required solution. There are 60+ predictive modelling algorithms to choose from. We must understand the type of problem and solution requirement to narrow down to a select few models which we can evaluate. Our problem is a mean squared error regression problem. We are also performing a category of machine learning which is called supervised learning as we are training our model with a given dataset.

# %%
# Features
X = df.drop('price',axis=1)

# Label
y = df['price']

# Split
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.3,random_state=101)

# %%
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (15129, 19)
# (6484, 19)
# (15129,)
# (6484,)

# %% [markdown]
# ### Normalizing / scaling the data
# We scale the feature data. To prevent data leakage from the test set, we only fit our scaler to the training set.

# %%
scaler = MinMaxScaler()

# fit and transfrom
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# everything has been scaled between 1 and 0
print('Max: ',X_train.max())
print('Min: ', X_train.min())
# Out:
# Max:  1.0000000000000002
# Min:  0.0

# %% [markdown]
# <a id="ch7"></a>
# ## Creating a model
# ***
# We estimate the number of neurons (units) from our features. Ex: X_train.shape (15117, 19). The optimizer is asking how you want to perform this gradient descent. In this case we are using the Adam optimizer and the mean square error loss function.

# %%
model = Sequential()

# input layer
model.add(Dense(19,activation='relu'))

# hidden layers
model.add(Dense(19,activation='relu'))
model.add(Dense(19,activation='relu'))
model.add(Dense(19,activation='relu'))

# output layer
model.add(Dense(1))

model.compile(optimizer='adam',loss='mse')

# %% [markdown]
# <a id="ch8"></a>
# ## Training the model
# ***
# Now that the model is ready, we can fit the model into the data.
#
# Since the dataset is large, we are going to use batch_size. It is typical to use batches of the power of 2 (32, 64, 128, 256...). In this case we are using 128. The smaller the batch size, the longer is going to take.

# %%
model.fit(x=X_train,y=y_train.values,
          validation_data=(X_test,y_test.values),
          batch_size=128,epochs=400)
# Out:
# Epoch 1/400
# 119/119 [==============================] - 2s 4ms/step - loss: 423625523200.0000 - val_loss: 433003528192.0000
# Epoch 2/400
# 119/119 [==============================] - 0s 2ms/step - loss: 422426705920.0000 - val_loss: 428690538496.0000
# Epoch 3/400
# 119/119 [==============================] - 0s 2ms/step - loss: 405245198336.0000 - val_loss: 388356472832.0000
# Epoch 4/400
# 119/119 [==============================] - 0s 2ms/step - loss: 320822542336.0000 - val_loss: 250852622336.0000
# Epoch 5/400
# 119/119 [==============================] - 0s 2ms/step - loss: 165235998720.0000 - val_loss: 115701030912.0000
# Epoch 6/400
# 119/119 [==============================] - 0s 2ms/step - loss: 101099282432.0000 - val_loss: 103684792320.0000
# Epoch 7/400
# 119/119 [==============================] - 0s 2ms/step - loss: 97687298048.0000 - val_loss: 101977350144.0000
# Epoch 8/400
# 119/119 [==============================] - 0s 2ms/step - loss: 96157573120.0000 - val_loss: 100324524032.0000
# Epoch 9/400
# 119/119 [==============================] - 0s 2ms/step - loss: 94582358016.0000 - val_loss: 98665897984.0000
# Epoch 10/400
# 119/119 [==============================] - 0s 3ms/step - loss: 93009534976.0000 - val_loss: 96853778432.0000
# Epoch 11/400
# 119/119 [==============================] - 0s 3ms/step - loss: 91378302976.0000 - val_loss: 95081365504.0000
# Epoch 12/400
# 119/119 [==============================] - 0s 3ms/step - loss: 89697525760.0000 - val_loss: 93178781696.0000
# 119/119 [==============================] - 0s 2ms/step - loss: 27683577856.0000 - val_loss: 27865004032.0000
# Epoch 398/400
# 119/119 [==============================] - 0s 3ms/step - loss: 27657621504.0000 - val_loss: 27832086528.0000
# Epoch 399/400
# 119/119 [==============================] - 0s 2ms/step - loss: 27629590528.0000 - val_loss: 27736723456.0000
# Epoch 400/400
# 119/119 [==============================] - 0s 2ms/step - loss: 27593648128.0000 - val_loss: 27690450944.0000

# %% [markdown]
# ### Training loss per epoch
# * This plot shows the training loss per epoch.
# * This plot helps us to see if there is overfitting in the model. In this case there is no overfitting because both lines go down at the same time.

# %%
losses = pd.DataFrame(model.history.history)

plt.figure(figsize=(15,5))
sns.lineplot(data=losses,lw=3)
plt.xlabel('Epochs')
plt.ylabel('')
plt.title('Training Loss per Epoch')
sns.despine()

# %% [markdown]
# <a id="ch9"></a>
# ## Evaluation on test data
# ---
# ### Regression Evaluation Metrics
#
# **Mean Absolute Error** (MAE) is the mean of the absolute value of the errors:
#
# $$\frac 1n\sum_{i=1}^n|y_i-\hat{y}_i|$$
#
# **Mean Squared Error** (MSE) is the mean of the squared errors:
#
# $$\frac 1n\sum_{i=1}^n(y_i-\hat{y}_i)^2$$
#
# **Root Mean Squared Error** (RMSE) is the square root of the mean of the squared errors:
#
# $$\sqrt{\frac 1n\sum_{i=1}^n(y_i-\hat{y}_i)^2}$$
#
# Comparing these metrics:
#
# - **MAE** is the easiest to understand, because it's the average error.
# - **MSE** is more popular than MAE, because MSE "punishes" larger errors, which tends to be useful in the real world.
# - **RMSE** is even more popular than MSE, because RMSE is interpretable in the "y" units.

# %% [markdown]
# ### Predicting on brand new data
# In this part we are giving the model the test set to get a list of predictions. Then we compare the correct values with the list of predictions. We use different metrics to compare the predictions, in this case we use MAE, MSE, RMSE and Variance Regression Score.
#
# Let us start by analyzing the MAE, which is \\$103,500. This means that our model is off on average about \\$100,000.
#
# ***Is that MAE good or bad?***
#
# For that we must take into account our original data set and see what kind of values we have. For instance, the mean is 540,000, therefore the MEA is about 19% of the mean price. This is not a particularly good result.
#
# To better understand this error, we can use the variance regression score, where the best possible score is 1.0 and lower values are worse. This tells you how much variance is being explain by your model. In our case we have 0.80 which is a normal result.

# %%
# predictions on the test set
predictions = model.predict(X_test)

print('MAE: ',mean_absolute_error(y_test,predictions))
print('MSE: ',mean_squared_error(y_test,predictions))
print('RMSE: ',np.sqrt(mean_squared_error(y_test,predictions)))
print('Variance Regression Score: ',explained_variance_score(y_test,predictions))

print('\n\nDescriptive Statistics:\n',df['price'].describe())
# Out:
# 203/203 [==============================] - 0s 1ms/step
# MAE:  103019.66227203501
# MSE:  27690449607.167614
# RMSE:  166404.47592287778
# Variance Regression Score:  0.8026035327608911
#
#
# Descriptive Statistics:
#  count    2.161300e+04
# mean     5.400881e+05
# std      3.671272e+05
# min      7.500000e+04
# 25%      3.219500e+05
# 50%      4.500000e+05
# 75%      6.450000e+05
# max      7.700000e+06
# Name: price, dtype: float64

# %% [markdown]
# ### Model predictions vs perfect fit
# * We can compare the model predictions with a perfect fit to see how accurate the model is.
# * The red line represents the perfect prediction.
# * We are being punish by the outliers, which are the expensive houses. Our model is not good predicting luxury houses.
# * On the other hand, our model is good predicting the price of houses between o and \\$2 million. There is clearly a good fit.
# * It may be worth it retraining our model just on price houses below \\$3 million.

# %%
f, axes = plt.subplots(1, 2,figsize=(15,5))

# Our model predictions
plt.scatter(y_test,predictions)

# Perfect predictions
plt.plot(y_test,y_test,'r')

errors = y_test.values.reshape(6484, 1) - predictions
sns.distplot(errors, ax=axes[0])

sns.despine(left=True, bottom=True)
axes[0].set(xlabel='Error', ylabel='', title='Error Histogram')
axes[1].set(xlabel='Test True Y', ylabel='Model Predictions', title='Model Predictions vs Perfect Fit')
# Out:
# C:\Users\meetr\AppData\Local\Temp\ipykernel_6208\3744242700.py:10: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(errors, ax=axes[0])
# [Text(0.5, 0, 'Test True Y'),
#  Text(0, 0.5, 'Model Predictions'),
#  Text(0.5, 1.0, 'Model Predictions vs Perfect Fit')]

# %% [markdown]
# <a id="ch10"></a>
# ## Predicting on a brand new house
# ---
# We are going to use the model to predict the price on a brand-new house. We are going to choose the first house of the data set and drop the price. single_house is going to have all the features that we need to predict the price. After that we need to reshape the variable and scale the features.
#
# The original price is \\$221,900 and the model prediction is \\$280,000.

# %%
# fueatures of new house
single_house = df.drop('price',axis=1).iloc[0]
print(f'Features of new house:\n{single_house}')

# reshape the numpy array and scale the features
single_house = scaler.transform(single_house.values.reshape(-1, 19))

# run the model and get the price prediction
print('\nPrediction Price:',model.predict(single_house)[0,0])

# original price
print('\nOriginal Price:',df.iloc[0]['price'])
# Out:
# Features of new house:
# bedrooms            3.0000
# bathrooms           1.0000
# sqft_living      1180.0000
# sqft_lot         5650.0000
# floors              1.0000
# waterfront          0.0000
# view                0.0000
# condition           3.0000
# grade               7.0000
# sqft_above       1180.0000
# sqft_basement       0.0000
# yr_built         1955.0000
# yr_renovated        0.0000
# lat                47.5112
# long             -122.2570
# sqft_living15    1340.0000
# sqft_lot15       5650.0000
# month              10.0000
# year             2014.0000
# Name: 0, dtype: float64
# 1/1 [==============================] - 0s 22ms/step
#
# Prediction Price: 285156.0
#
# Original Price: 221900.0
# C:\Users\meetr\anaconda3\lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.svm import SVR
from sklearn.metrics import mean_squared_error

# Extract the required columns for training
X = df[['bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot', 'floors', 'waterfront', 'view', 
        'condition', 'grade', 'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated',
        'lat', 'long', 'sqft_living15', 'sqft_lot15']]
y = df['price']

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# Standardize the data
sc_X = StandardScaler()
X_train = sc_X.fit_transform(X_train)
X_test = sc_X.transform(X_test)

# Train the SVM model
svm_model = SVR(kernel='rbf')
svm_model.fit(X_train, y_train)

# Predictions on the test set
y_pred = svm_model.predict(X_test)

# Print the predictions
print("Predictions:")
for i in range(len(y_pred)):
    print(f"Predicted price: {y_pred[i]}, Actual price: {y_test.iloc[i]}")

# Calculate and print the mean squared error
mse = mean_squared_error(y_test, y_pred)
print(f"Mean Squared Error: {mse}")

# Train the SVM model
svm_model = SVR(kernel='rbf')
svm_model.fit(X_train, y_train)

# Predictions on the test set
y_pred = svm_model.predict(X_test)

# Print the predictions
print("Predictions:")
for i in range(len(y_pred)):
    print(f"Predicted price: {y_pred[i]}, Actual price: {y_test.iloc[i]}")

# Calculate and print the mean squared error
mse = mean_squared_error(y_test, y_pred)
print(f"Mean Squared Error: {mse}")
# Out:
# Predictions:
# Predicted price: 452814.9692378002, Actual price: 297000.0
# Predicted price: 454031.49140641815, Actual price: 1578000.0
# Predicted price: 452122.16449435445, Actual price: 562100.0
# Predicted price: 452214.6223406901, Actual price: 631500.0
# Predicted price: 454264.13240775233, Actual price: 780000.0
# Predicted price: 452781.8274111564, Actual price: 485000.0
# Predicted price: 452226.27266654145, Actual price: 340000.0
# Predicted price: 452836.57719017076, Actual price: 335606.0
# Predicted price: 453580.704089716, Actual price: 425000.0
# Predicted price: 453953.97197965014, Actual price: 490000.0
# Predicted price: 453324.4622449733, Actual price: 732000.0
# Predicted price: 452885.65428545483, Actual price: 389700.0
# Predicted price: 452822.20498167403, Actual price: 450000.0
# Predicted price: 451917.98717047926, Actual price: 357000.0
# Predicted price: 454168.9580230158, Actual price: 960000.0
# Predicted price: 452160.16252067237, Actual price: 257000.0
# Predicted price: 452617.6528891496, Actual price: 448000.0
# Predicted price: 453088.002821537, Actual price: 610000.0
# Predicted price: 452351.36862088053, Actual price: 230950.0
# Predicted price: 453179.5040813483, Actual price: 377500.0
# Predicted price: 451895.2725360319, Actual price: 375000.0
# Predicted price: 452637.60105030297, Actual price: 410000.0
# Predicted price: 453506.6339349251, Actual price: 459000.0
# Predicted price: 451341.74258860556, Actual price: 190000.0
# Predicted price: 453400.8543760428, Actual price: 585000.0
# Predicted price: 451766.09826941387, Actual price: 280000.0
# Predicted price: 452390.2578108426, Actual price: 500000.0
# Predicted price: 452838.25055582984, Actual price: 465000.0
# Predicted price: 453429.99872271094, Actual price: 802000.0
# Predicted price: 452171.6711740167, Actual price: 440000.0
# Predicted price: 453442.994717806, Actual price: 1452000.0
# Predicted price: 452727.5882457148, Actual price: 575000.0
# Predicted price: 453107.05920722045, Actual price: 390000.0
# Predicted price: 454552.1349171673, Actual price: 1210000.0
# Predicted price: 454389.5355009501, Actual price: 858000.0
# Predicted price: 452178.5131405166, Actual price: 453000.0
# Predicted price: 452256.2083845386, Actual price: 245000.0
# Predicted price: 452457.0261568292, Actual price: 279000.0
# Predicted price: 453402.0134069185, Actual price: 482000.0
# Predicted price: 451366.2333109441, Actual price: 228500.0
# Predicted price: 452059.24866451236, Actual price: 397990.0
# Predicted price: 452610.80834513245, Actual price: 400000.0
# Predicted price: 452499.93806256005, Actual price: 325000.0
# Predicted price: 453711.11586913647, Actual price: 699000.0
# Predicted price: 453340.6007740262, Actual price: 555000.0
# Predicted price: 453767.1575885799, Actual price: 687000.0
# Predicted price: 452622.05537551065, Actual price: 310000.0
# Predicted price: 453774.6000930041, Actual price: 400000.0
# Predicted price: 452456.2514701101, Actual price: 525000.0
# Predicted price: 454569.66119374865, Actual price: 1035000.0
# Predicted price: 451480.8204149859, Actual price: 255000.0
# Predicted price: 452314.091563861, Actual price: 245000.0
# Predicted price: 453878.4045901864, Actual price: 1325000.0
# Predicted price: 452203.9281171351, Actual price: 309212.0
# Predicted price: 454667.06085069606, Actual price: 782000.0
# Predicted price: 451936.3809706656, Actual price: 553000.0
# Predicted price: 452529.24188310496, Actual price: 390500.0
# Predicted price: 452538.0697013105, Actual price: 330000.0
# Predicted price: 452076.49021202396, Actual price: 425000.0
# Predicted price: 453416.7584777152, Actual price: 552500.0
# Predicted price: 452337.46522260056, Actual price: 308000.0
# Predicted price: 452485.7368012525, Actual price: 320000.0
# Predicted price: 452303.5599540711, Actual price: 382000.0
# Predicted price: 453533.99615850346, Actual price: 435000.0
# Predicted price: 453347.3499219793, Actual price: 372000.0
# Predicted price: 454351.0678764607, Actual price: 1381000.0
# Predicted price: 452009.5862784605, Actual price: 349950.0
# Predicted price: 452772.5470098553, Actual price: 350000.0
# Predicted price: 454262.41005348536, Actual price: 1315000.0
# Predicted price: 452612.4612101293, Actual price: 255000.0
# Predicted price: 453817.5094655117, Actual price: 405000.0
# Predicted price: 452943.8138661061, Actual price: 442500.0
# Predicted price: 453276.7882554472, Actual price: 772000.0
# Predicted price: 453204.5974537875, Actual price: 767450.0
# Predicted price: 454365.63263050665, Actual price: 832000.0
# Predicted price: 454422.9682140051, Actual price: 835000.0
# Predicted price: 453447.2889952633, Actual price: 2000000.0
# Predicted price: 453620.3498539285, Actual price: 460000.0
# Predicted price: 452042.7235897872, Actual price: 500000.0
# Predicted price: 453616.7371085872, Actual price: 620000.0
# Predicted price: 453448.25084147434, Actual price: 605000.0
# Predicted price: 453500.358315288, Actual price: 790000.0
# Predicted price: 453649.2492428478, Actual price: 1749000.0
# Predicted price: 453431.72902954073, Actual price: 513000.0
# Predicted price: 453599.55662094813, Actual price: 600000.0
# Predicted price: 453054.3417187462, Actual price: 680000.0
# Predicted price: 452888.6275198911, Actual price: 350000.0
# Predicted price: 452288.9960088325, Actual price: 332000.0
# Predicted price: 452482.8186577845, Actual price: 605000.0
# Predicted price: 451869.8230230384, Actual price: 325000.0
# Predicted price: 453614.4799934109, Actual price: 1680000.0
# Predicted price: 453393.73344703775, Actual price: 555000.0
# Predicted price: 453286.77231031115, Actual price: 565000.0
# Predicted price: 452900.76920226705, Actual price: 480000.0
# Predicted price: 453827.8219122544, Actual price: 3204000.0
# Predicted price: 452233.3315308016, Actual price: 215000.0
# Predicted price: 453059.6725856345, Actual price: 605000.0
# Predicted price: 454378.2969257122, Actual price: 623000.0
# Predicted price: 452175.38082520827, Actual price: 536000.0
# Predicted price: 452631.67919902026, Actual price: 370000.0
# Predicted price: 451269.9962047974, Actual price: 203000.0
# Predicted price: 453368.5149719613, Actual price: 420000.0
# Predicted price: 453924.6014290215, Actual price: 575000.0
# Predicted price: 454015.9820758178, Actual price: 1795000.0
# Predicted price: 452254.3095175701, Actual price: 985000.0
# Predicted price: 453281.0974152197, Actual price: 412950.0
# Predicted price: 452154.5989587152, Actual price: 285000.0
# Predicted price: 453105.38271521707, Actual price: 614306.0
# Predicted price: 451645.35015567404, Actual price: 450000.0
# Predicted price: 452084.594155901, Actual price: 206000.0
# Predicted price: 452786.107202881, Actual price: 490000.0
# Predicted price: 454443.0326527039, Actual price: 960000.0
# Predicted price: 451463.89136380766, Actual price: 248000.0
# Predicted price: 453805.67664349126, Actual price: 540000.0
# Predicted price: 453240.2241252317, Actual price: 344200.0
# Predicted price: 454330.5654464776, Actual price: 940000.0
# Predicted price: 452765.1227887989, Actual price: 440500.0
# Predicted price: 452661.56852655124, Actual price: 515000.0
# Predicted price: 453241.36211574136, Actual price: 635500.0
# Predicted price: 454330.6662806167, Actual price: 679950.0
# Predicted price: 452106.20655833714, Actual price: 216000.0
# Predicted price: 452213.0564037754, Actual price: 304000.0
# Predicted price: 451945.8727191291, Actual price: 315000.0
# Predicted price: 454168.50395841914, Actual price: 650000.0
# Predicted price: 452339.5632931373, Actual price: 460000.0
# Predicted price: 451830.2115508211, Actual price: 178500.0
# Predicted price: 451376.4038043358, Actual price: 215000.0
# Predicted price: 452969.07548622583, Actual price: 550000.0
# Predicted price: 451507.5496831573, Actual price: 333000.0
# Predicted price: 451411.4671503702, Actual price: 325000.0
# Predicted price: 453498.66654160566, Actual price: 535000.0
# Predicted price: 451860.39365243266, Actual price: 425000.0
# Predicted price: 451916.89281512337, Actual price: 358000.0
# Predicted price: 451457.6067704844, Actual price: 220000.0
# Predicted price: 453442.7819887225, Actual price: 621500.0
# Predicted price: 451812.9128167655, Actual price: 194000.0
# Predicted price: 453711.6128598932, Actual price: 438900.0
# Predicted price: 452160.5831072298, Actual price: 235000.0
# Predicted price: 452581.44690106163, Actual price: 280000.0
# Predicted price: 453258.37035580265, Actual price: 627800.0
# Predicted price: 453524.36035344197, Actual price: 408000.0
# Predicted price: 451628.2054312046, Actual price: 205000.0
# Predicted price: 454176.9778328866, Actual price: 796500.0
# Predicted price: 451798.8778478164, Actual price: 265000.0
# Predicted price: 451208.9653259847, Actual price: 242000.0
# Predicted price: 453681.5563755794, Actual price: 502000.0
# Predicted price: 453791.64646879066, Actual price: 607500.0
# Predicted price: 452609.3451571418, Actual price: 215000.0
# Predicted price: 453749.1998606948, Actual price: 502000.0
# Predicted price: 453022.89311616635, Actual price: 320000.0
# Predicted price: 454610.48245277937, Actual price: 955000.0
# Predicted price: 453267.6851105885, Actual price: 372000.0
# Predicted price: 452927.05985572713, Actual price: 375000.0
# Predicted price: 452922.4887108209, Actual price: 254500.0
# Predicted price: 451635.64518329944, Actual price: 168000.0
# Predicted price: 453603.9468783761, Actual price: 700000.0
# Predicted price: 453251.68109476386, Actual price: 323000.0
# Predicted price: 454041.757359226, Actual price: 725995.0
# Predicted price: 452193.13627890527, Actual price: 325000.0
# Predicted price: 452664.80411816796, Actual price: 275000.0
# Predicted price: 451781.73982164735, Actual price: 330000.0
# Predicted price: 453450.9332200791, Actual price: 2600000.0
# Predicted price: 453878.7443031585, Actual price: 577288.0
# Predicted price: 452430.25210558745, Actual price: 512500.0
# Predicted price: 452846.77318435366, Actual price: 589000.0
# Predicted price: 452181.6600533157, Actual price: 275436.0
# Predicted price: 452330.4334689282, Actual price: 179000.0
# Predicted price: 453431.4723569866, Actual price: 580000.0
# Predicted price: 452577.4881122177, Actual price: 308000.0
# Predicted price: 451416.1387617274, Actual price: 235000.0
# Predicted price: 452163.0736854422, Actual price: 371000.0
# Predicted price: 452347.325213935, Actual price: 290000.0
# Predicted price: 454502.05259925313, Actual price: 699000.0
# Predicted price: 451952.6866082982, Actual price: 463500.0
# Predicted price: 453704.91986829904, Actual price: 895000.0
# Predicted price: 451927.5050448849, Actual price: 294950.0
# Predicted price: 453293.0169995041, Actual price: 385000.0
# Predicted price: 453809.7795849807, Actual price: 2350000.0
# Predicted price: 451880.4693919659, Actual price: 189000.0
# Predicted price: 452546.95216448425, Actual price: 321000.0
# Predicted price: 451420.192361034, Actual price: 269500.0
# Predicted price: 451928.44266403647, Actual price: 250000.0
# Predicted price: 453098.1114748379, Actual price: 436500.0
# Predicted price: 453244.04112382716, Actual price: 480000.0
# Predicted price: 451596.76147818903, Actual price: 310000.0
# Predicted price: 452097.6517301573, Actual price: 269950.0
# Predicted price: 451430.66867232765, Actual price: 268950.0
# Predicted price: 453565.0786611335, Actual price: 985000.0
# Predicted price: 454102.36560575373, Actual price: 2250000.0
# Predicted price: 453454.1205499477, Actual price: 620000.0
# Predicted price: 451412.2102116727, Actual price: 241000.0
# Predicted price: 452155.9793337509, Actual price: 305000.0
# Predicted price: 452371.7825036593, Actual price: 368000.0
# Predicted price: 452953.5487269169, Actual price: 305000.0
# Predicted price: 454017.96127819957, Actual price: 639000.0
# Predicted price: 453510.4751188693, Actual price: 787500.0
# Predicted price: 451393.24867040344, Actual price: 150000.0
# Predicted price: 453417.75892409746, Actual price: 395000.0
# Predicted price: 453196.5427446873, Actual price: 415000.0
# Predicted price: 452988.509509747, Actual price: 323000.0
# Predicted price: 452284.17251496535, Actual price: 305000.0
# Predicted price: 452644.74392515025, Actual price: 670000.0
# Predicted price: 452017.9020563845, Actual price: 396000.0
# Predicted price: 454400.1207792329, Actual price: 880000.0
# Predicted price: 451976.560880554, Actual price: 330000.0
# Predicted price: 452944.9037165496, Actual price: 203000.0
# Predicted price: 454499.16423350066, Actual price: 900000.0
# Predicted price: 452698.80774384004, Actual price: 366000.0
# Predicted price: 453949.84302704013, Actual price: 414000.0
# Predicted price: 452174.962491212, Actual price: 305000.0
# Predicted price: 451511.6617392484, Actual price: 307150.0
# Predicted price: 452728.1091573839, Actual price: 405000.0
# Predicted price: 451284.79297066026, Actual price: 260000.0
# Predicted price: 453250.87884574145, Actual price: 466000.0
# Predicted price: 451764.8346834239, Actual price: 698000.0
# Predicted price: 452304.51283861266, Actual price: 460000.0
# Predicted price: 452908.921954329, Actual price: 195000.0
# Predicted price: 454423.28515229037, Actual price: 854000.0
# Predicted price: 453967.62511672516, Actual price: 770000.0
# Predicted price: 452372.0974495152, Actual price: 443000.0
# Predicted price: 452464.1585528879, Actual price: 385500.0
# Predicted price: 454526.2011205994, Actual price: 783350.0
# Predicted price: 453525.3568969782, Actual price: 464500.0
# Predicted price: 452581.6050123557, Actual price: 384000.0
# Predicted price: 452261.2461724063, Actual price: 445000.0
# Predicted price: 451776.8879591279, Actual price: 447000.0
# Predicted price: 451794.78582059394, Actual price: 292500.0
# Predicted price: 453466.0448424022, Actual price: 600000.0
# Predicted price: 452939.82709103584, Actual price: 326000.0
# Predicted price: 451409.300455161, Actual price: 435010.0
# Predicted price: 453555.85482507135, Actual price: 449950.0
# Predicted price: 453391.9582157871, Actual price: 383962.0
# Predicted price: 453422.7838779771, Actual price: 382000.0
# Predicted price: 453119.42502318276, Actual price: 737000.0
# Predicted price: 452106.42484400544, Actual price: 352500.0
# Predicted price: 453819.5335566558, Actual price: 525000.0
# Predicted price: 452286.7129834846, Actual price: 285000.0
# Predicted price: 453287.0120840206, Actual price: 530000.0
# Predicted price: 452974.2603407783, Actual price: 437000.0
# Predicted price: 452960.6530560582, Actual price: 410000.0
# Predicted price: 453829.0263134226, Actual price: 589000.0
# Predicted price: 453997.5912231979, Actual price: 959750.0
# Predicted price: 452851.26582051604, Actual price: 396000.0
# Predicted price: 452909.5004495632, Actual price: 655000.0
# Predicted price: 451831.7149481022, Actual price: 246900.0
# Predicted price: 452806.31675094325, Actual price: 540000.0
# Predicted price: 453708.8103073135, Actual price: 520000.0
# Predicted price: 452834.0084440746, Actual price: 344900.0
# Predicted price: 451756.8526432563, Actual price: 295000.0
# Predicted price: 453420.7484724531, Actual price: 399000.0
# Predicted price: 452350.93661187676, Actual price: 475000.0
# Predicted price: 452546.1888941917, Actual price: 345000.0
# Predicted price: 453911.3111949924, Actual price: 580000.0
# Predicted price: 451376.19743772765, Actual price: 215000.0
# Predicted price: 453469.1014230001, Actual price: 400000.0
# Predicted price: 453565.0672946989, Actual price: 554990.0
# Predicted price: 452180.15002144524, Actual price: 435000.0
# Predicted price: 453023.2199101853, Actual price: 355000.0
# Predicted price: 451389.34775753994, Actual price: 180250.0
# Predicted price: 451787.56754532433, Actual price: 160000.0
# Predicted price: 452463.1509975094, Actual price: 290000.0
# Predicted price: 452684.94569612417, Actual price: 355000.0
# Predicted price: 452255.5001312382, Actual price: 165000.0
# Predicted price: 452522.11101478484, Actual price: 525000.0
# Predicted price: 451933.70193916204, Actual price: 253905.0
# Predicted price: 453187.3015692179, Actual price: 395000.0
# Predicted price: 453949.3758553648, Actual price: 925000.0
# Predicted price: 451258.6112373767, Actual price: 210000.0
# Predicted price: 453245.3248663377, Actual price: 710000.0
# Predicted price: 452078.26656133076, Actual price: 299000.0
# Predicted price: 453209.143971576, Actual price: 480000.0
# Predicted price: 454244.98943584546, Actual price: 585000.0
# Predicted price: 454342.1751394546, Actual price: 1875000.0
# Predicted price: 453066.73368887074, Actual price: 365000.0
# Predicted price: 451274.20062151627, Actual price: 309000.0
# Predicted price: 451382.1597484556, Actual price: 226800.0
# Predicted price: 451485.3279877182, Actual price: 165000.0
# Predicted price: 453439.4433528217, Actual price: 480000.0
# Predicted price: 453932.27933442686, Actual price: 645000.0
# Predicted price: 451950.88909684913, Actual price: 235000.0
# Predicted price: 452839.07621906593, Actual price: 415000.0
# Predicted price: 452014.39046078007, Actual price: 575000.0
# Predicted price: 452785.48068275774, Actual price: 350000.0
# Predicted price: 453796.1252550604, Actual price: 610000.0
# Predicted price: 453835.4608949156, Actual price: 1300000.0
# Predicted price: 451530.846949733, Actual price: 315000.0
# Predicted price: 452362.944802834, Actual price: 402200.0
# Predicted price: 451384.4254615643, Actual price: 250000.0
# Predicted price: 452421.7451312862, Actual price: 436000.0
# Predicted price: 453207.709665553, Actual price: 412000.0
# Predicted price: 453350.71549043036, Actual price: 562000.0
# Predicted price: 453333.81602311786, Actual price: 726500.0
# Predicted price: 452883.44494498067, Actual price: 325000.0
# Predicted price: 454113.8010996695, Actual price: 675000.0
# Predicted price: 451857.17554032983, Actual price: 269000.0
# Predicted price: 452372.5914489186, Actual price: 490000.0
# Predicted price: 453634.65309974377, Actual price: 465425.0
# Predicted price: 452602.76768395776, Actual price: 272000.0
# Predicted price: 453221.09730385523, Actual price: 299000.0
# Predicted price: 453197.56036247633, Actual price: 556000.0
# Predicted price: 451595.7247267742, Actual price: 279950.0
# Predicted price: 453851.32570218283, Actual price: 750000.0
# Predicted price: 451934.10840409057, Actual price: 510000.0
# Predicted price: 452283.02057027887, Actual price: 681000.0
# Predicted price: 453615.31829650013, Actual price: 780000.0
# Predicted price: 454032.63770998345, Actual price: 666000.0
# Predicted price: 452673.5639554884, Actual price: 950000.0
# Predicted price: 453827.4080018323, Actual price: 2250000.0
# Predicted price: 452297.13642005925, Actual price: 580000.0
# Predicted price: 453468.9996623808, Actual price: 1065000.0
# Predicted price: 452632.6207288684, Actual price: 570000.0
# Predicted price: 451832.9780096059, Actual price: 276000.0
# Predicted price: 453175.1475243354, Actual price: 490000.0
# Predicted price: 453392.33546035603, Actual price: 924000.0
# Predicted price: 451476.46289752144, Actual price: 219000.0
# Predicted price: 452947.96423757076, Actual price: 550000.0
# Predicted price: 453213.7323941459, Actual price: 361550.0
# Predicted price: 451977.08997107134, Actual price: 268000.0
# Predicted price: 453560.8911868468, Actual price: 1280000.0
# Predicted price: 452005.51918758696, Actual price: 245000.0
# Predicted price: 451327.2098179903, Actual price: 238000.0
# Predicted price: 453553.50608387694, Actual price: 725000.0
# Predicted price: 453203.6475757076, Actual price: 440000.0
# Predicted price: 453128.1542544709, Actual price: 360000.0
# Predicted price: 452840.8868643399, Actual price: 315000.0
# Predicted price: 452706.2060461231, Actual price: 290000.0
# Predicted price: 452565.6592570241, Actual price: 457000.0
# Predicted price: 451526.1371064253, Actual price: 247500.0
# Predicted price: 452054.15846492647, Actual price: 285000.0
# Predicted price: 452906.3526821251, Actual price: 450000.0
# Predicted price: 453596.7757959689, Actual price: 725000.0
# Predicted price: 454313.129789824, Actual price: 1660000.0
# Predicted price: 452625.67327709234, Actual price: 613000.0
# Predicted price: 454155.411101474, Actual price: 1450000.0
# Predicted price: 453885.96721806, Actual price: 1045000.0
# Predicted price: 451615.0074191546, Actual price: 180000.0
# Predicted price: 453836.0260257958, Actual price: 1265000.0
# Predicted price: 451954.0864381899, Actual price: 199500.0
# Predicted price: 454151.869669366, Actual price: 729000.0
# Predicted price: 451307.1065685884, Actual price: 197500.0
# Predicted price: 453154.2489614635, Actual price: 375000.0
# Predicted price: 451897.5701532261, Actual price: 414500.0
# Predicted price: 453170.721384528, Actual price: 363000.0
# Predicted price: 453553.3350980604, Actual price: 1681000.0
# Predicted price: 451257.12500470306, Actual price: 223000.0
# Predicted price: 452712.63866427116, Actual price: 450000.0
# Predicted price: 454520.5365241507, Actual price: 864327.0
# Predicted price: 451949.3692843038, Actual price: 424000.0
# Predicted price: 453850.6337890897, Actual price: 1462500.0
# Predicted price: 453084.4727760797, Actual price: 346290.0
# Predicted price: 451359.72330964473, Actual price: 216500.0
# Predicted price: 453360.45063105604, Actual price: 492500.0
# Predicted price: 451925.3965352691, Actual price: 232603.0
# Predicted price: 454297.2614854399, Actual price: 908950.0
# Predicted price: 453729.24433012516, Actual price: 1195000.0
# Predicted price: 453020.8389507515, Actual price: 455000.0
# Predicted price: 451803.6615280367, Actual price: 270000.0
# Predicted price: 452734.1126142258, Actual price: 475000.0
# Predicted price: 452698.52908679977, Actual price: 310950.0
# Predicted price: 451665.85456982034, Actual price: 228900.0
# Predicted price: 452668.5250674501, Actual price: 381500.0
# Predicted price: 453178.8194797678, Actual price: 535000.0
# Predicted price: 451771.4952486266, Actual price: 124000.0
# Predicted price: 451261.8757292422, Actual price: 219000.0
# Predicted price: 451727.73430045263, Actual price: 442000.0
# Predicted price: 453163.85759312735, Actual price: 465250.0
# Predicted price: 453836.90831983415, Actual price: 592500.0
# Predicted price: 451823.549343056, Actual price: 267000.0
# Predicted price: 454497.5282334117, Actual price: 1149000.0
# Predicted price: 452705.3240623329, Actual price: 725000.0
# Predicted price: 452671.9585074394, Actual price: 382000.0
# Predicted price: 454153.26258588635, Actual price: 747500.0
# Predicted price: 452977.26732418494, Actual price: 410000.0
# Predicted price: 453759.58727068314, Actual price: 853505.0
# Predicted price: 453019.59257229144, Actual price: 509950.0
# Predicted price: 451380.8541485285, Actual price: 274000.0
# Predicted price: 451879.63910116756, Actual price: 370000.0
# Predicted price: 452392.8787319234, Actual price: 350000.0
# Predicted price: 453289.7424319653, Actual price: 398651.0
# Predicted price: 453150.37195065536, Actual price: 340000.0
# Predicted price: 453863.1553913979, Actual price: 610000.0
# Predicted price: 452694.4315154037, Actual price: 415000.0
# Predicted price: 453511.7226209883, Actual price: 480000.0
# Predicted price: 452830.25600761006, Actual price: 302500.0
# Predicted price: 453156.07117210276, Actual price: 418000.0
# Predicted price: 452378.78628943977, Actual price: 273000.0
# Predicted price: 451672.298481008, Actual price: 550000.0
# Predicted price: 451341.0137770717, Actual price: 212000.0
# Predicted price: 451358.75169231236, Actual price: 414000.0
# Predicted price: 452015.68121965457, Actual price: 247500.0
# Predicted price: 452177.6036264743, Actual price: 599950.0
# Predicted price: 451540.565481417, Actual price: 284200.0
# Predicted price: 453394.9679419681, Actual price: 805000.0
# Predicted price: 452383.7249564793, Actual price: 299000.0
# Predicted price: 453564.2799414597, Actual price: 379000.0
# Predicted price: 453480.2072094305, Actual price: 4208000.0
# Predicted price: 452650.76385599317, Actual price: 467000.0
# Predicted price: 452896.6611758743, Actual price: 778000.0
# Predicted price: 453588.91224737716, Actual price: 1362500.0
# Predicted price: 452779.8501924107, Actual price: 398000.0
# Predicted price: 451551.07388101233, Actual price: 435000.0
# Predicted price: 453342.14863092, Actual price: 715000.0
# Predicted price: 453353.48849559925, Actual price: 505000.0
# Predicted price: 451778.8117185272, Actual price: 305000.0
# Predicted price: 453189.69200659025, Actual price: 648752.0
# Predicted price: 451574.74822450284, Actual price: 210000.0
# Predicted price: 452286.6441367813, Actual price: 280000.0
# Predicted price: 453224.28268353594, Actual price: 375500.0
# Predicted price: 452227.9059809604, Actual price: 362000.0
# Predicted price: 453671.4058473182, Actual price: 515000.0
# Predicted price: 452555.44450151187, Actual price: 796000.0
# Predicted price: 452911.1372261669, Actual price: 468000.0
# Predicted price: 451360.2196260303, Actual price: 187500.0
# Predicted price: 451928.4607582621, Actual price: 225800.0
# Predicted price: 452111.12185365433, Actual price: 484000.0
# Predicted price: 452246.2795532855, Actual price: 295000.0
# Predicted price: 453836.86733880924, Actual price: 365000.0
# Predicted price: 451998.3532642139, Actual price: 489000.0
# Predicted price: 452677.82665180747, Actual price: 350000.0
# Predicted price: 452743.7435552258, Actual price: 287500.0
# Predicted price: 452366.0000809396, Actual price: 325000.0
# Predicted price: 453006.69074046117, Actual price: 550000.0
# Predicted price: 451825.4668918278, Actual price: 406000.0
# Predicted price: 453847.96820762864, Actual price: 1225000.0
# Predicted price: 453402.9814175503, Actual price: 318000.0
# Predicted price: 452628.03687680996, Actual price: 805000.0
# Predicted price: 451956.1754387839, Actual price: 310000.0
# Predicted price: 453829.05888595636, Actual price: 600000.0
# Predicted price: 452523.0109035879, Actual price: 411715.0
# Predicted price: 453687.6861723937, Actual price: 489000.0
# Predicted price: 453560.8594959534, Actual price: 499000.0
# Predicted price: 452114.03245912073, Actual price: 237000.0
# Predicted price: 451785.2303684389, Actual price: 365000.0
# Predicted price: 452492.77223969944, Actual price: 565000.0
# Predicted price: 451974.86097233393, Actual price: 255950.0
# Predicted price: 453617.30449641455, Actual price: 588000.0
# Predicted price: 453363.05427968426, Actual price: 666000.0
# Predicted price: 454115.009796485, Actual price: 542126.0
# Predicted price: 451728.02649711794, Actual price: 355000.0
# Predicted price: 452383.3701495538, Actual price: 430100.0
# Predicted price: 453037.86300473195, Actual price: 609000.0
# Predicted price: 453526.1362476294, Actual price: 515000.0
# Predicted price: 452129.40840838326, Actual price: 389000.0
# Predicted price: 451503.0095260629, Actual price: 203000.0
# Predicted price: 453887.1178199177, Actual price: 2300000.0
# Predicted price: 453461.4128405706, Actual price: 559000.0
# Predicted price: 454098.76029678405, Actual price: 1105000.0
# Predicted price: 453180.54491302423, Actual price: 611206.0
# Predicted price: 454050.8235327627, Actual price: 630000.0
# Predicted price: 452812.1155779746, Actual price: 690000.0
# Predicted price: 453437.2078484103, Actual price: 685000.0
# Predicted price: 452261.01692671294, Actual price: 690000.0
# Predicted price: 453472.2930002846, Actual price: 480000.0
# Predicted price: 452500.5139537845, Actual price: 240000.0
# Predicted price: 454395.7131887704, Actual price: 1065000.0
# Predicted price: 453046.69482024474, Actual price: 513000.0
# Predicted price: 453096.4628841371, Actual price: 538000.0
# Predicted price: 452482.1212837693, Actual price: 439995.0
# Predicted price: 454212.1121288298, Actual price: 485000.0
# Predicted price: 451329.6971661824, Actual price: 244500.0
# Predicted price: 453661.12616069673, Actual price: 449950.0
# Predicted price: 452944.16426953254, Actual price: 448500.0
# Predicted price: 453334.5092186594, Actual price: 470000.0
# Predicted price: 453342.67301682406, Actual price: 432900.0
# Predicted price: 452628.6176915062, Actual price: 375000.0
# Predicted price: 452080.71005033504, Actual price: 250000.0
# Predicted price: 452330.814181475, Actual price: 347000.0
# Predicted price: 452083.5721121807, Actual price: 299999.0
# Predicted price: 454332.9996052265, Actual price: 1025000.0
# Predicted price: 451315.8336462226, Actual price: 205000.0
# Predicted price: 452897.9480218575, Actual price: 319000.0
# Predicted price: 453462.2502822902, Actual price: 456500.0
# Predicted price: 452057.881133035, Actual price: 464950.0
# Predicted price: 453505.85979863774, Actual price: 606000.0
# Predicted price: 452298.13874253986, Actual price: 474905.0
# Predicted price: 451189.3485849948, Actual price: 120000.0
# Predicted price: 453235.45649379294, Actual price: 308130.0
# Predicted price: 451201.0119054743, Actual price: 205000.0
# Predicted price: 451961.3039706048, Actual price: 350000.0
# Predicted price: 452892.6469509054, Actual price: 500000.0
# Predicted price: 453271.1856172747, Actual price: 467000.0
# Predicted price: 453739.93783950957, Actual price: 1115000.0
# Predicted price: 452096.77028724155, Actual price: 630000.0
# Predicted price: 451578.7293768241, Actual price: 207000.0
# Predicted price: 452544.1678637685, Actual price: 450000.0
# Predicted price: 453844.1501202221, Actual price: 710000.0
# Predicted price: 452522.70391647634, Actual price: 370000.0
# Predicted price: 453751.78036615235, Actual price: 1580000.0
# Predicted price: 451952.96002355515, Actual price: 818900.0
# Predicted price: 451972.5668141014, Actual price: 271900.0
# Predicted price: 451597.058257435, Actual price: 260000.0
# Predicted price: 453792.2182564107, Actual price: 540000.0
# Predicted price: 451636.12660434435, Actual price: 216000.0
# Predicted price: 454269.6539895818, Actual price: 1225000.0
# Predicted price: 453437.5137063523, Actual price: 2700000.0
# Predicted price: 452942.19836561877, Actual price: 439000.0
# Predicted price: 453428.03873749, Actual price: 300000.0
# Predicted price: 453903.5658978042, Actual price: 1110000.0
# Predicted price: 453179.61690609896, Actual price: 440500.0
# Predicted price: 452912.33875707106, Actual price: 425000.0
# Predicted price: 453661.41795071, Actual price: 1100000.0
# Predicted price: 452897.8663565104, Actual price: 530000.0
# Predicted price: 453043.33470127167, Actual price: 564800.0
# Predicted price: 451756.7072431488, Actual price: 307500.0
# Predicted price: 452067.29383058334, Actual price: 217000.0
# Predicted price: 453890.6055301394, Actual price: 1220000.0
# Predicted price: 452819.58615530113, Actual price: 375000.0
# Predicted price: 451984.39060477127, Actual price: 565000.0
# Predicted price: 451851.17433230457, Actual price: 405000.0
# Predicted price: 452852.9554840086, Actual price: 703011.0
# Predicted price: 452344.80217640556, Actual price: 289500.0
# Predicted price: 452985.5217668669, Actual price: 340000.0
# Predicted price: 453789.5418191339, Actual price: 490000.0
# Predicted price: 453749.7113346161, Actual price: 637000.0
# Predicted price: 452403.78140551544, Actual price: 610000.0
# Predicted price: 451966.44899093785, Actual price: 269950.0
# Predicted price: 452540.54271807615, Actual price: 380500.0
# Predicted price: 453756.264970286, Actual price: 889000.0
# Predicted price: 453335.8163960887, Actual price: 390000.0
# Predicted price: 452402.31492092216, Actual price: 385000.0
# Predicted price: 454310.7455922744, Actual price: 950000.0
# Predicted price: 451463.3937885989, Actual price: 340000.0
# Predicted price: 453214.7392589425, Actual price: 750000.0
# Predicted price: 453935.28664770856, Actual price: 1175000.0
# Predicted price: 452284.9980104799, Actual price: 424000.0
# Predicted price: 452535.4730815445, Actual price: 520000.0
# Predicted price: 453043.7579587125, Actual price: 374950.0
# Predicted price: 452315.9152054389, Actual price: 443000.0
# Predicted price: 451942.43429780676, Actual price: 360000.0
# Predicted price: 453499.2584318124, Actual price: 420000.0
# Predicted price: 454590.82521641505, Actual price: 879000.0
# Predicted price: 452480.59020046965, Actual price: 452000.0
# Predicted price: 451335.0465923783, Actual price: 199988.0
# Predicted price: 451499.93929164566, Actual price: 275000.0
# Predicted price: 451847.7982462613, Actual price: 350000.0
# Predicted price: 453452.27408436744, Actual price: 579000.0
# Predicted price: 454078.8399656832, Actual price: 1385000.0
# Predicted price: 453158.42613810056, Actual price: 375000.0
# Predicted price: 453599.8645547286, Actual price: 1100000.0
# Predicted price: 453599.597031003, Actual price: 655000.0
# Predicted price: 452933.00709824916, Actual price: 380000.0
# Predicted price: 453814.27033902466, Actual price: 950000.0
# Predicted price: 453745.14350768074, Actual price: 565000.0
# Predicted price: 451794.72368342895, Actual price: 254000.0
# Predicted price: 451581.22310082894, Actual price: 278000.0
# Predicted price: 453121.6556503379, Actual price: 375000.0
# Predicted price: 454402.9625583683, Actual price: 800000.0
# Predicted price: 452391.0448748027, Actual price: 481000.0
# Predicted price: 453919.80578983604, Actual price: 1157200.0
# Predicted price: 451386.8034330317, Actual price: 180000.0
# Predicted price: 452872.445146011, Actual price: 380000.0
# Predicted price: 453607.5280474348, Actual price: 1535000.0
# Predicted price: 453240.84735101776, Actual price: 437000.0
# Predicted price: 452444.86932393466, Actual price: 425500.0
# Predicted price: 453774.3876779019, Actual price: 504750.0
# Predicted price: 452029.07261527603, Actual price: 299950.0
# Predicted price: 452245.20709270396, Actual price: 290256.0
# Predicted price: 451943.119183987, Actual price: 750000.0
# Predicted price: 452480.063742312, Actual price: 326500.0
# Predicted price: 453114.5129609556, Actual price: 550000.0
# Predicted price: 453325.03435182985, Actual price: 539950.0
# Predicted price: 453393.6760207102, Actual price: 510000.0
# Predicted price: 452655.23074608226, Actual price: 349950.0
# Predicted price: 452892.08853455447, Actual price: 498000.0
# Predicted price: 453393.5943122111, Actual price: 340000.0
# Predicted price: 453018.4918207368, Actual price: 400000.0
# Predicted price: 453031.72749837796, Actual price: 515000.0
# Predicted price: 453084.88550257223, Actual price: 676101.0
# Predicted price: 452517.77844023105, Actual price: 320000.0
# Predicted price: 452839.64943399065, Actual price: 548000.0
# Predicted price: 453595.6968851614, Actual price: 1245000.0
# Predicted price: 452638.9161919302, Actual price: 330000.0
# Predicted price: 453437.3880516323, Actual price: 387500.0
# Predicted price: 452724.5533820143, Actual price: 540000.0
# Predicted price: 453693.897298812, Actual price: 716000.0
# Predicted price: 451616.865029121, Actual price: 550000.0
# Predicted price: 451851.0124406221, Actual price: 319000.0
# Predicted price: 451846.30445191765, Actual price: 161500.0
# Predicted price: 452333.2434981068, Actual price: 199000.0
# Predicted price: 452137.4790626426, Actual price: 375000.0
# Predicted price: 453938.1126094796, Actual price: 670000.0
# Predicted price: 453411.83215480094, Actual price: 416100.0
# Predicted price: 451554.96505053056, Actual price: 253500.0
# Predicted price: 451453.5383047076, Actual price: 224000.0
# Predicted price: 453362.0415093718, Actual price: 398500.0
# Predicted price: 453247.4501082275, Actual price: 728050.0
# Predicted price: 454157.0464765716, Actual price: 655000.0
# Predicted price: 452982.1135267907, Actual price: 386000.0
# Predicted price: 451774.1445586397, Actual price: 135000.0
# Predicted price: 452357.96191541274, Actual price: 395000.0
# Predicted price: 453893.45855955046, Actual price: 760000.0
# Predicted price: 451645.60938105005, Actual price: 499950.0
# Predicted price: 452012.0893494376, Actual price: 270000.0
# Predicted price: 452208.6232126696, Actual price: 272000.0
# Predicted price: 453592.12158937246, Actual price: 1060000.0
# Predicted price: 451792.1516338438, Actual price: 239975.0
# Predicted price: 453407.15439373755, Actual price: 810000.0
# Predicted price: 452050.1299289386, Actual price: 187000.0
# Predicted price: 451285.6625732286, Actual price: 252000.0
# Predicted price: 453372.3116449088, Actual price: 367950.0
# Predicted price: 451286.0557732518, Actual price: 195000.0
# Predicted price: 452518.1652413121, Actual price: 430000.0
# Predicted price: 454005.1404660575, Actual price: 2175000.0
# Predicted price: 454458.1625818319, Actual price: 797000.0
# Predicted price: 452263.12095019943, Actual price: 590000.0
# Predicted price: 451655.2638872115, Actual price: 420000.0
# Predicted price: 452150.7480744944, Actual price: 240000.0
# Predicted price: 451315.86896093265, Actual price: 196440.0
# Predicted price: 452281.8484941711, Actual price: 248000.0
# Predicted price: 454424.38658320834, Actual price: 675000.0
# Predicted price: 452265.49362819525, Actual price: 405000.0
# Predicted price: 451520.06491284963, Actual price: 235000.0
# Predicted price: 453122.95263807237, Actual price: 250000.0
# Predicted price: 452550.0089361286, Actual price: 525000.0
# Predicted price: 454134.16144740663, Actual price: 1038000.0
# Predicted price: 451663.95921981824, Actual price: 400000.0
# Predicted price: 452739.2016972182, Actual price: 613000.0
# Predicted price: 452129.64041271026, Actual price: 390000.0
# Predicted price: 453616.7240837959, Actual price: 1200000.0
# Predicted price: 452682.87636435195, Actual price: 429950.0
# Predicted price: 451525.14387454535, Actual price: 175409.0
# Predicted price: 454311.6317174307, Actual price: 1000000.0
# Predicted price: 453318.1977172741, Actual price: 297000.0
# Predicted price: 451759.9796354039, Actual price: 266750.0
# Predicted price: 452994.9620785695, Actual price: 315000.0
# Predicted price: 451310.2016994422, Actual price: 285000.0
# Predicted price: 451939.97106231755, Actual price: 190000.0
# Predicted price: 451670.8134892899, Actual price: 274950.0
# Predicted price: 454538.12620890216, Actual price: 814950.0
# Predicted price: 452457.94384073577, Actual price: 426000.0
# Predicted price: 453577.671960952, Actual price: 799000.0
# Predicted price: 451524.2936965867, Actual price: 430000.0
# Predicted price: 452813.528190147, Actual price: 572000.0
# Predicted price: 453553.6404255873, Actual price: 585000.0
# Predicted price: 452410.0871006062, Actual price: 315000.0
# Predicted price: 452096.66017721914, Actual price: 210000.0
# Predicted price: 451596.92517926934, Actual price: 270000.0
# Predicted price: 453613.8239615372, Actual price: 565000.0
# Predicted price: 452255.0253402944, Actual price: 270000.0
# Predicted price: 452805.4205427272, Actual price: 690000.0
# Predicted price: 452039.93193384854, Actual price: 306000.0
# Predicted price: 454458.5565992045, Actual price: 798000.0
# Predicted price: 454329.5591875237, Actual price: 826000.0
# Predicted price: 451491.70275214105, Actual price: 250000.0
# Predicted price: 454120.5145608138, Actual price: 760000.0
# Predicted price: 454049.86536590965, Actual price: 585000.0
# Predicted price: 451833.07033425453, Actual price: 490000.0
# Predicted price: 452932.2864101052, Actual price: 392000.0
# Predicted price: 452129.0251800408, Actual price: 380000.0
# Predicted price: 452418.5565135753, Actual price: 365000.0
# Predicted price: 453282.99659586465, Actual price: 1050000.0
# Predicted price: 453442.1977498884, Actual price: 408506.0
# Predicted price: 453044.7754766285, Actual price: 415000.0
# Predicted price: 452015.99859523785, Actual price: 236000.0
# Predicted price: 452337.26365060074, Actual price: 315000.0
# Predicted price: 452045.587718453, Actual price: 310000.0
# Predicted price: 453894.5685449985, Actual price: 575000.0
# Predicted price: 453265.51131399855, Actual price: 160000.0
# Predicted price: 452321.3320728197, Actual price: 310000.0
# Predicted price: 452946.707684205, Actual price: 530000.0
# Predicted price: 453317.66646264395, Actual price: 510000.0
# Predicted price: 454606.1106527293, Actual price: 800000.0
# Predicted price: 452643.42025287234, Actual price: 300000.0
# Predicted price: 452563.7009313414, Actual price: 395000.0
# Predicted price: 453892.0016359961, Actual price: 699000.0
# Predicted price: 451450.2218653803, Actual price: 353000.0
# Predicted price: 452156.8118164792, Actual price: 297000.0
# Predicted price: 453738.020203343, Actual price: 637000.0
# Predicted price: 454477.13196869177, Actual price: 920000.0
# Predicted price: 452800.93529517786, Actual price: 385000.0
# Predicted price: 453999.85870116565, Actual price: 583000.0
# Predicted price: 452615.76630495186, Actual price: 360000.0
# Predicted price: 452566.04480025545, Actual price: 436000.0
# Predicted price: 453037.3922650595, Actual price: 400000.0
# Predicted price: 452009.12331461726, Actual price: 450000.0
# Predicted price: 452461.7331703083, Actual price: 328000.0
# Predicted price: 452377.4301943027, Actual price: 345000.0
# Predicted price: 452202.16697275254, Actual price: 299000.0
# Predicted price: 453802.71889651124, Actual price: 750000.0
# Predicted price: 453239.1854157689, Actual price: 300000.0
# Predicted price: 454017.82962998096, Actual price: 692000.0
# Predicted price: 452928.9349959556, Actual price: 500000.0
# Predicted price: 453916.17857572285, Actual price: 969950.0
# Predicted price: 451412.6909046921, Actual price: 261000.0
# Predicted price: 452540.0791454053, Actual price: 355500.0
# Predicted price: 454208.58799928677, Actual price: 595000.0
# Predicted price: 453423.6010562933, Actual price: 356000.0
# Predicted price: 452344.9850715943, Actual price: 355000.0
# Predicted price: 451927.6046451855, Actual price: 265000.0
# Predicted price: 451864.02854756266, Actual price: 190000.0
# Predicted price: 451294.54680167825, Actual price: 203000.0
# Predicted price: 453122.41374548385, Actual price: 383000.0
# Predicted price: 454259.6598073872, Actual price: 717000.0
# Predicted price: 451962.4527363294, Actual price: 362500.0
# Predicted price: 453348.65557544155, Actual price: 779000.0
# Predicted price: 451844.94221710897, Actual price: 252000.0
# Predicted price: 451902.3713479188, Actual price: 199000.0
# Predicted price: 453303.17884654115, Actual price: 427500.0
# Predicted price: 454449.0969486212, Actual price: 1565000.0
# Predicted price: 453068.0091525082, Actual price: 406100.0
# Predicted price: 451619.3891667049, Actual price: 360000.0
# Predicted price: 453776.1592965965, Actual price: 659000.0
# Predicted price: 453377.5096816538, Actual price: 589000.0
# Predicted price: 454463.3146554787, Actual price: 1061600.0
# Predicted price: 453485.96107990365, Actual price: 449950.0
# Predicted price: 453589.76961512637, Actual price: 396500.0
# Predicted price: 454024.08327109605, Actual price: 1850000.0
# Predicted price: 452074.9094015571, Actual price: 463000.0
# Predicted price: 453026.8767318914, Actual price: 335000.0
# Predicted price: 453317.4064401637, Actual price: 565000.0
# Predicted price: 454597.3625344948, Actual price: 820000.0
# Predicted price: 453578.49099174445, Actual price: 1275000.0
# Predicted price: 452406.75125120534, Actual price: 279000.0
# Predicted price: 452074.48765191226, Actual price: 336000.0
# Predicted price: 453145.9367378002, Actual price: 437500.0
# Predicted price: 453307.41156873805, Actual price: 385000.0
# Predicted price: 451784.6695217344, Actual price: 260000.0
# Predicted price: 452111.8669558436, Actual price: 315000.0
# Predicted price: 453269.92719418247, Actual price: 420000.0
# Predicted price: 451470.14651341946, Actual price: 222000.0
# Predicted price: 454308.84820879175, Actual price: 700000.0
# Predicted price: 452463.2088337486, Actual price: 445000.0
# Predicted price: 453744.1645189689, Actual price: 585000.0
# Predicted price: 451421.51794700604, Actual price: 219950.0
# Predicted price: 451958.69667274767, Actual price: 350000.0
# Predicted price: 451367.85555680795, Actual price: 210000.0
# Predicted price: 451990.97759817244, Actual price: 499000.0
# Predicted price: 452256.079345609, Actual price: 275000.0
# Predicted price: 452340.8109378248, Actual price: 700000.0
# Predicted price: 451747.6725365033, Actual price: 284000.0
# Predicted price: 452055.33084865974, Actual price: 530000.0
# Predicted price: 451844.0918402443, Actual price: 261500.0
# Predicted price: 453563.1654123333, Actual price: 790000.0
# Predicted price: 451795.0348213204, Actual price: 319950.0
# Predicted price: 451493.8659779822, Actual price: 315000.0
# Predicted price: 453515.42438219854, Actual price: 423000.0
# Predicted price: 452875.3765819586, Actual price: 383000.0
# Predicted price: 453844.1730873415, Actual price: 937500.0
# Predicted price: 453617.1163103449, Actual price: 790000.0
# Predicted price: 451778.696320569, Actual price: 233703.0
# Predicted price: 453147.2223939634, Actual price: 326000.0
# Predicted price: 451889.33201208577, Actual price: 285650.0
# Predicted price: 452164.5713296916, Actual price: 291000.0
# Predicted price: 451808.307515915, Actual price: 512500.0
# Predicted price: 453942.0198975235, Actual price: 639983.0
# Predicted price: 453946.2514249233, Actual price: 1375000.0
# Predicted price: 451649.36399770185, Actual price: 189000.0
# Predicted price: 454203.4354475328, Actual price: 731000.0
# Predicted price: 451450.2795309382, Actual price: 200000.0
# Predicted price: 453138.3306443585, Actual price: 535000.0
# Predicted price: 453218.31829512154, Actual price: 561750.0
# Predicted price: 453048.38339607953, Actual price: 521000.0
# Predicted price: 452908.2841943981, Actual price: 525000.0
# Predicted price: 453713.375485313, Actual price: 499950.0
# Predicted price: 452793.1086453455, Actual price: 386000.0
# Predicted price: 452415.4368681846, Actual price: 455000.0
# Predicted price: 454122.9329023414, Actual price: 642860.0
# Predicted price: 451890.7558693924, Actual price: 263000.0
# Predicted price: 451482.0267674749, Actual price: 253200.0
# Predicted price: 453722.7956819163, Actual price: 590000.0
# Predicted price: 451994.0012423952, Actual price: 320000.0
# Predicted price: 453430.8681614012, Actual price: 401500.0
# Predicted price: 453189.7032664249, Actual price: 299000.0
# Predicted price: 452268.31225595536, Actual price: 250000.0
# Predicted price: 452412.0208455382, Actual price: 319000.0
# Predicted price: 453083.1074866134, Actual price: 291000.0
# Predicted price: 452326.82072858553, Actual price: 800000.0
# Predicted price: 452907.35708335316, Actual price: 425000.0
# Predicted price: 454444.13591332425, Actual price: 685000.0
# Predicted price: 452034.48457584676, Actual price: 426000.0
# Predicted price: 452409.0386820694, Actual price: 220000.0
# Predicted price: 452678.716824878, Actual price: 358000.0
# Predicted price: 452078.83857214986, Actual price: 250000.0
# Predicted price: 452102.8304580048, Actual price: 213400.0
# Predicted price: 453998.51206594537, Actual price: 495000.0
# Predicted price: 454347.0457648515, Actual price: 828950.0
# Predicted price: 452750.73444843455, Actual price: 575000.0
# Predicted price: 452464.5371300039, Actual price: 308000.0
# Predicted price: 452057.87838579266, Actual price: 161000.0
# Predicted price: 454113.26653056854, Actual price: 1015000.0
# Predicted price: 453025.5775642025, Actual price: 500000.0
# Predicted price: 451835.75103552244, Actual price: 245000.0
# Predicted price: 451987.6792100133, Actual price: 389000.0
# Predicted price: 453209.4762762228, Actual price: 470000.0
# Predicted price: 451278.96939782664, Actual price: 122000.0
# Predicted price: 452272.0852912491, Actual price: 315000.0
# Predicted price: 454083.2008695507, Actual price: 619990.0
# Predicted price: 454546.92694453674, Actual price: 1070000.0
# Predicted price: 451448.025413251, Actual price: 465000.0
# Predicted price: 452325.5261826831, Actual price: 299000.0
# Predicted price: 453232.1519137708, Actual price: 430000.0
# Predicted price: 453880.5974312788, Actual price: 800000.0
# Predicted price: 453530.56233263324, Actual price: 585000.0
# Predicted price: 452654.66080050735, Actual price: 259000.0
# Predicted price: 452443.71898046177, Actual price: 392500.0
# Predicted price: 453316.8775062023, Actual price: 498000.0
# Predicted price: 452330.2242099398, Actual price: 309000.0
# Predicted price: 453239.6946436501, Actual price: 423000.0
# Predicted price: 454489.5756698278, Actual price: 925900.0
# Predicted price: 454482.75116012717, Actual price: 885000.0
# Predicted price: 452797.61678589834, Actual price: 662500.0
# Predicted price: 453835.5430122394, Actual price: 940000.0
# Predicted price: 453142.40796313476, Actual price: 780000.0
# Predicted price: 452283.18074752716, Actual price: 275000.0
# Predicted price: 453240.59083350794, Actual price: 1038000.0
# Predicted price: 453437.92442238337, Actual price: 540000.0
# Predicted price: 453663.7709268963, Actual price: 1328000.0
# ...
# Predicted price: 453102.87652102776, Actual price: 356200.0
# Predicted price: 452761.3959106069, Actual price: 395900.0
# Predicted price: 451811.13564321207, Actual price: 279000.0
# Predicted price: 452921.56685971847, Actual price: 362950.0
# Predicted price: 453523.00460288435, Actual price: 467000.0
# Predicted price: 453818.12796252174, Actual price: 959000.0
# Predicted price: 452710.86313457607, Actual price: 371500.0
# Predicted price: 453048.5263763608, Actual price: 560000.0
# Predicted price: 451873.3500344018, Actual price: 247000.0
# Predicted price: 453192.1766611644, Actual price: 450000.0
# Predicted price: 452378.6853752432, Actual price: 511500.0
# Predicted price: 451263.46874679945, Actual price: 200000.0
# Predicted price: 452041.72126731806, Actual price: 400000.0
# Predicted price: 452221.30328050436, Actual price: 738000.0
# Predicted price: 453775.2041311731, Actual price: 1075000.0
# Predicted price: 452065.41151362145, Actual price: 535000.0
# Predicted price: 452599.4258063993, Actual price: 287000.0
# Predicted price: 453020.968387036, Actual price: 530000.0
# Predicted price: 454160.7568044588, Actual price: 1250000.0
# Predicted price: 453424.956906731, Actual price: 575000.0
# Predicted price: 452310.3790666983, Actual price: 305000.0
# Predicted price: 451985.81146128004, Actual price: 352000.0
# Predicted price: 453078.64018496743, Actual price: 368000.0
# Predicted price: 453500.8162343597, Actual price: 925000.0
# Predicted price: 453584.2109142338, Actual price: 1075000.0
# Predicted price: 453550.90733980027, Actual price: 540000.0
# Predicted price: 452936.92022786045, Actual price: 328000.0
# Predicted price: 453443.7875618751, Actual price: 864000.0
# Predicted price: 453853.5431191252, Actual price: 600000.0
# Predicted price: 452171.0332763277, Actual price: 375000.0
# Predicted price: 451979.1860358013, Actual price: 400000.0
# Predicted price: 453438.45666782116, Actual price: 1920000.0
# Predicted price: 452876.37285085145, Actual price: 453000.0
# Predicted price: 451510.032807549, Actual price: 172000.0
# Predicted price: 452313.6581893419, Actual price: 400000.0
# Predicted price: 452716.14876103186, Actual price: 354450.0
# Predicted price: 451439.9833913477, Actual price: 245000.0
# Predicted price: 453130.5009923742, Actual price: 260000.0
# Predicted price: 451860.99077526963, Actual price: 195000.0
# Predicted price: 452821.4960187012, Actual price: 280000.0
# Predicted price: 453413.76162743656, Actual price: 265000.0
# Predicted price: 454562.8625570906, Actual price: 751000.0
# Predicted price: 453426.2308428183, Actual price: 563500.0
# Predicted price: 452514.3984454442, Actual price: 340000.0
# Predicted price: 452711.3243192427, Actual price: 365070.0
# Predicted price: 452071.50650347874, Actual price: 285000.0
# Predicted price: 454562.1987430963, Actual price: 963000.0
# Predicted price: 452917.3149636011, Actual price: 469000.0
# Predicted price: 452730.53809664806, Actual price: 509500.0
# Predicted price: 452309.0673851649, Actual price: 280000.0
# Predicted price: 453148.8852945557, Actual price: 354950.0
# Predicted price: 452147.7049737716, Actual price: 300000.0
# Predicted price: 453468.1494043868, Actual price: 750000.0
# Predicted price: 452173.72632772813, Actual price: 749000.0
# Predicted price: 451464.6214806331, Actual price: 203700.0
# Predicted price: 453569.3783535538, Actual price: 895000.0
# Predicted price: 452245.4833246221, Actual price: 430000.0
# Predicted price: 452593.6899307753, Actual price: 535000.0
# Predicted price: 452683.5557724184, Actual price: 399950.0
# Predicted price: 452885.1902454104, Actual price: 500000.0
# Predicted price: 451585.0487237917, Actual price: 450000.0
# Predicted price: 452745.28505359683, Actual price: 676000.0
# Predicted price: 451777.78155380883, Actual price: 223990.0
# Predicted price: 453678.6336246632, Actual price: 1049000.0
# Predicted price: 451177.1665471946, Actual price: 196900.0
# Predicted price: 452597.54258775205, Actual price: 452950.0
# Predicted price: 452632.2582639807, Actual price: 439500.0
# Predicted price: 454604.2052052407, Actual price: 875000.0
# Predicted price: 453934.3360536992, Actual price: 530000.0
# Predicted price: 453030.930161778, Actual price: 540000.0
# Predicted price: 454232.3542226401, Actual price: 1285000.0
# Predicted price: 453462.94290602294, Actual price: 500000.0
# Predicted price: 454151.49616115046, Actual price: 455000.0
# Predicted price: 453560.5009617595, Actual price: 760000.0
# Predicted price: 451315.7140092392, Actual price: 218250.0
# Predicted price: 452744.5389932669, Actual price: 369000.0
# Predicted price: 453268.5628886545, Actual price: 675000.0
# Predicted price: 453885.50190131104, Actual price: 1695000.0
# Predicted price: 452518.5386380898, Actual price: 384500.0
# Predicted price: 451878.2098529101, Actual price: 217000.0
# Predicted price: 454067.2750132439, Actual price: 1218000.0
# Predicted price: 453477.72837666876, Actual price: 410000.0
# Predicted price: 452706.6031469966, Actual price: 500000.0
# Predicted price: 452661.279186849, Actual price: 329800.0
# Predicted price: 453080.0409679427, Actual price: 660000.0
# Predicted price: 452394.20185459574, Actual price: 350000.0
# Predicted price: 452319.54435878986, Actual price: 517000.0
# Predicted price: 454415.80383411795, Actual price: 994000.0
# Predicted price: 451737.0234775423, Actual price: 394475.0
# Predicted price: 452503.4721267796, Actual price: 180000.0
# Predicted price: 451549.3578057721, Actual price: 130000.0
# Predicted price: 452979.60580162687, Actual price: 390000.0
# Predicted price: 453969.30783276306, Actual price: 1385000.0
# Predicted price: 454373.5416352285, Actual price: 369900.0
# Predicted price: 452829.7468246663, Actual price: 560000.0
# Predicted price: 454065.2120326212, Actual price: 1155000.0
# Predicted price: 453422.7739223915, Actual price: 1135000.0
# Predicted price: 452709.8286525335, Actual price: 260000.0
# Predicted price: 452983.0026090719, Actual price: 560000.0
# Predicted price: 452578.4873774256, Actual price: 470000.0
# Predicted price: 453197.16917891457, Actual price: 525000.0
# Predicted price: 452365.44687480095, Actual price: 282000.0
# Predicted price: 451532.4368001335, Actual price: 370000.0
# Predicted price: 453238.21366543375, Actual price: 399950.0
# Predicted price: 453562.6994103414, Actual price: 585000.0
# Predicted price: 453422.44421696756, Actual price: 352000.0
# Predicted price: 452427.6626644006, Actual price: 638000.0
# Predicted price: 453669.0430991184, Actual price: 860000.0
# Predicted price: 453493.683866217, Actual price: 390000.0
# Predicted price: 453830.0708602869, Actual price: 913888.0
# Predicted price: 453559.1826291879, Actual price: 590000.0
# Predicted price: 452705.7931326865, Actual price: 320000.0
# Predicted price: 451566.83784121735, Actual price: 328000.0
# Predicted price: 454596.7243581958, Actual price: 911000.0
# Predicted price: 453667.83462349436, Actual price: 355425.0
# Predicted price: 453946.09458723984, Actual price: 965000.0
# Predicted price: 454287.59137536393, Actual price: 595000.0
# Predicted price: 453422.9019197822, Actual price: 710000.0
# Predicted price: 452887.36918033916, Actual price: 574500.0
# Predicted price: 452653.34577514615, Actual price: 315000.0
# Predicted price: 451910.9660955863, Actual price: 350000.0
# Predicted price: 454257.4910688733, Actual price: 815000.0
# Predicted price: 453019.17578718567, Actual price: 340000.0
# Predicted price: 452774.4792860922, Actual price: 316500.0
# Predicted price: 452503.60335902474, Actual price: 512500.0
# Predicted price: 453429.69476958417, Actual price: 5570000.0
# Predicted price: 452972.8915269012, Actual price: 602000.0
# Predicted price: 451529.1035760187, Actual price: 400000.0
# Predicted price: 452247.80985123187, Actual price: 410000.0
# Predicted price: 452677.2707470313, Actual price: 345500.0
# Predicted price: 451510.80762134696, Actual price: 290300.0
# Predicted price: 451982.30193229875, Actual price: 252000.0
# Predicted price: 453537.86061548116, Actual price: 868000.0
# Predicted price: 453841.2333728722, Actual price: 450000.0
# Predicted price: 452544.8980266673, Actual price: 405100.0
# Predicted price: 454147.7439975523, Actual price: 2250000.0
# Predicted price: 452272.1573595793, Actual price: 515000.0
# Predicted price: 451607.58727650956, Actual price: 250000.0
# Predicted price: 451775.90663061535, Actual price: 525000.0
# Predicted price: 451906.7439854174, Actual price: 202500.0
# Predicted price: 453079.17247435724, Actual price: 545000.0
# Predicted price: 451459.1306841704, Actual price: 255000.0
# Predicted price: 453632.0745990141, Actual price: 896000.0
# Predicted price: 452863.3139914169, Actual price: 500000.0
# Predicted price: 454446.55471590423, Actual price: 765000.0
# Predicted price: 453445.805048546, Actual price: 930000.0
# Predicted price: 451375.1876059085, Actual price: 237000.0
# Predicted price: 452655.2156506504, Actual price: 299000.0
# Predicted price: 451528.3975136984, Actual price: 291000.0
# Predicted price: 453356.54022418405, Actual price: 750000.0
# Predicted price: 451992.36204774777, Actual price: 439000.0
# Predicted price: 452111.40254568675, Actual price: 316000.0
# Predicted price: 453396.81299332663, Actual price: 399950.0
# Predicted price: 453627.68764772435, Actual price: 465000.0
# Predicted price: 452354.10552649025, Actual price: 363000.0
# Predicted price: 452855.15501742845, Actual price: 476000.0
# Predicted price: 452423.7083993906, Actual price: 440150.0
# Predicted price: 453225.29581411695, Actual price: 621000.0
# Predicted price: 451211.4013675951, Actual price: 208000.0
# Predicted price: 451471.07871966856, Actual price: 249500.0
# Predicted price: 453937.8603684335, Actual price: 575000.0
# Predicted price: 453358.2687170069, Actual price: 504500.0
# Predicted price: 454379.6978649722, Actual price: 887250.0
# Predicted price: 454359.5284542442, Actual price: 845000.0
# Predicted price: 452923.58488846524, Actual price: 615000.0
# Predicted price: 451277.0886150412, Actual price: 199950.0
# Predicted price: 454128.74253988726, Actual price: 1067000.0
# Predicted price: 452391.6161899286, Actual price: 445000.0
# Predicted price: 454189.410677975, Actual price: 523000.0
# Predicted price: 453137.4935261844, Actual price: 420000.0
# Predicted price: 454311.0844826021, Actual price: 660000.0
# Predicted price: 451770.35539111827, Actual price: 300000.0
# Predicted price: 452939.134540119, Actual price: 325000.0
# Predicted price: 452955.5023325819, Actual price: 449000.0
# Predicted price: 454438.8717162845, Actual price: 1000000.0
# Predicted price: 453440.319300244, Actual price: 705000.0
# Predicted price: 453599.38915515493, Actual price: 545000.0
# Predicted price: 454428.3140241898, Actual price: 920000.0
# Predicted price: 452179.2499783651, Actual price: 252500.0
# Predicted price: 452285.89066886494, Actual price: 270000.0
# Predicted price: 453259.7202705265, Actual price: 630000.0
# Predicted price: 452544.9360924019, Actual price: 334900.0
# Predicted price: 453607.6005540954, Actual price: 597500.0
# Predicted price: 452370.9409849585, Actual price: 389000.0
# Predicted price: 452166.9997710646, Actual price: 329950.0
# Predicted price: 453366.24098759657, Actual price: 615000.0
# Predicted price: 451292.8332593059, Actual price: 230000.0
# Predicted price: 453006.2525345043, Actual price: 420000.0
# Predicted price: 452019.94705934665, Actual price: 600000.0
# Predicted price: 451582.4398166099, Actual price: 315000.0
# Predicted price: 453335.1731143475, Actual price: 432000.0
# Predicted price: 451926.77288075374, Actual price: 499950.0
# Predicted price: 451595.6650050978, Actual price: 293550.0
# Predicted price: 453368.6376999441, Actual price: 489950.0
# Predicted price: 452387.3953294184, Actual price: 409950.0
# Predicted price: 453015.58465368237, Actual price: 618080.0
# Predicted price: 451899.5408885413, Actual price: 475000.0
# Predicted price: 452224.90897502215, Actual price: 283200.0
# Predicted price: 452625.25410027424, Actual price: 590000.0
# Predicted price: 453874.34328204114, Actual price: 809000.0
# Predicted price: 452519.9933954447, Actual price: 399888.0
# Predicted price: 452868.1219264224, Actual price: 389000.0
# Predicted price: 452375.4660567172, Actual price: 482000.0
# Predicted price: 453580.9037198079, Actual price: 910000.0
# Predicted price: 454114.0104645941, Actual price: 940000.0
# Predicted price: 451500.00207747775, Actual price: 310000.0
# Predicted price: 452042.8402124485, Actual price: 465000.0
# Predicted price: 451526.23241113493, Actual price: 246000.0
# Predicted price: 453237.39019652276, Actual price: 360000.0
# Predicted price: 453752.9364194047, Actual price: 2250000.0
# Predicted price: 452909.4219742087, Actual price: 360000.0
# Predicted price: 452081.1815465091, Actual price: 469000.0
# Predicted price: 453336.5906030756, Actual price: 411000.0
# Predicted price: 451444.35188346857, Actual price: 299000.0
# Predicted price: 452035.38803173444, Actual price: 716000.0
# Predicted price: 452941.01588559913, Actual price: 260000.0
# Predicted price: 453700.28828401177, Actual price: 643000.0
# Predicted price: 452075.48742997815, Actual price: 338500.0
# Predicted price: 451370.7402959457, Actual price: 203000.0
# Predicted price: 453124.36947562976, Actual price: 460500.0
# Predicted price: 452857.0921082247, Actual price: 339990.0
# Predicted price: 453163.51852288854, Actual price: 432500.0
# Predicted price: 452587.05763184075, Actual price: 345950.0
# Predicted price: 453694.58926574787, Actual price: 471835.0
# Predicted price: 452805.2185321615, Actual price: 550000.0
# Predicted price: 451269.9568069678, Actual price: 225000.0
# Predicted price: 452845.22769927606, Actual price: 503000.0
# Predicted price: 451882.3306593596, Actual price: 261500.0
# Predicted price: 452929.4259865811, Actual price: 585000.0
# Predicted price: 451498.3023345129, Actual price: 314950.0
# Predicted price: 452986.02169322874, Actual price: 496800.0
# Predicted price: 451401.5107000768, Actual price: 300000.0
# Predicted price: 452724.01650971407, Actual price: 995000.0
# Predicted price: 452192.50476634724, Actual price: 255000.0
# Predicted price: 453998.1351246222, Actual price: 1095000.0
# Predicted price: 454359.9083283426, Actual price: 1580000.0
# Predicted price: 453618.4152047102, Actual price: 480000.0
# Predicted price: 452140.028672515, Actual price: 323000.0
# Predicted price: 453834.85152898193, Actual price: 1242000.0
# Predicted price: 451837.4393993334, Actual price: 411500.0
# Predicted price: 453313.1614937719, Actual price: 270000.0
# Predicted price: 453715.8370045769, Actual price: 725000.0
# Predicted price: 453907.02995378437, Actual price: 2400000.0
# Predicted price: 452149.86410843383, Actual price: 423000.0
# Predicted price: 451360.0141825094, Actual price: 250000.0
# Predicted price: 452901.7845820524, Actual price: 850000.0
# Predicted price: 454443.56539556355, Actual price: 925000.0
# Predicted price: 453964.02122219256, Actual price: 490000.0
# Predicted price: 451584.40417694824, Actual price: 200000.0
# Predicted price: 453754.53889191145, Actual price: 1675000.0
# Predicted price: 453239.80335300346, Actual price: 375000.0
# Predicted price: 452076.33795358846, Actual price: 339950.0
# Predicted price: 452461.081967716, Actual price: 516000.0
# Predicted price: 454493.394530226, Actual price: 802500.0
# Predicted price: 451273.1574126578, Actual price: 210000.0
# Predicted price: 452768.6117842519, Actual price: 565000.0
# Predicted price: 453059.43763104174, Actual price: 420000.0
# Predicted price: 452728.2480745508, Actual price: 500000.0
# Predicted price: 452575.22553937417, Actual price: 390000.0
# Predicted price: 452243.8563664878, Actual price: 228000.0
# Predicted price: 453096.71998061147, Actual price: 385000.0
# Predicted price: 452040.37020650733, Actual price: 550000.0
# Predicted price: 453419.80361928936, Actual price: 490000.0
# Predicted price: 454411.1936014587, Actual price: 844000.0
# Predicted price: 452262.4323166177, Actual price: 335500.0
# Predicted price: 452416.59000100463, Actual price: 369950.0
# Predicted price: 451544.56619567075, Actual price: 300000.0
# Predicted price: 452141.23797491693, Actual price: 575950.0
# Mean Squared Error: 124397302177.15009

# %% [markdown]
# ## References
# * [An Introduction to Statistical Learning with Applications in R](http://faculty.marshall.usc.edu/gareth-james/ISL/) - This book provides an introduction to statistical learning methods.
# * [Python for Data Science and Machine Learning Bootcamp](https://www.udemy.com/course/python-for-data-science-and-machine-learning-bootcamp/) - Use Python for Data Science and Machine Learning.

# %% [markdown]
# **Thank you** for taking the time to read through my first exploration of a Kaggle dataset. I look forward to doing more!
#
# If you have a question or feedback, do not hesitate to comment and if you like this kernel,<b><font color='green'> please upvote! </font></b>
